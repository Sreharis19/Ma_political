# %%
from googleapiclient.errors import HttpError
from time import sleep
import csv
import mysql.connector
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from googleapiclient.discovery import build
from newsapi import NewsApiClient
import http.client, urllib.parse
import json
import requests
import re
import tldextract
import fitz
from tenacity import retry, stop_after_attempt, wait_fixed, wait_exponential
from fuzzywuzzy import fuzz

from nltk.sentiment import SentimentIntensityAnalyzer  # Import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from fuzzywuzzy import fuzz

from summarizer import Summarizer

import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer, util

from concurrent.futures import ThreadPoolExecutor

# import tensorflow as tf
# print(tf.__version__)

# import torch
# print(torch.__version__)

import datefinder
from datetime import datetime
# Out:
# C:\Users\sreeh\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# API keys
# GOOGLE SEARCH API KEY AND SERVICE ID
# api_key = "AIzaSyDyTXqJQUaHaZMBkUbPvDDJYI1P3hLqmho"
# api_key = "AIzaSyDURaJMXTRBgo7NYmS4fYFVGheVGhuVtVg"
# api_key = "AIzaSyAoVQJw9bbxEQRyUD5hlsgrB7jdRAb_mZc"
# api_key = "AIzaSyBpMzVKKC2GFCFfbjwPPF9jJi84N20Z_Bc"
api_key = "AIzaSyCGHtCu5sL9M07kkVCkvUiz76skmXwoRMo"
# service_id = "1722146824011415a"
# service_id = "45f0f07fee2fd4e78"
service_id = "33c8102204e804e4d"

# Media Stack API key
mediaStack_key = "f738e0f304a2583969424193bb48ac7a"

# News Api key and url
news_api_url = 'https://newsapi.org/v2/everything'
news_api_key = '82f17a92a14942198554627cf3215656'



# Configure Google Search API
service = build("customsearch", "v1", developerKey=api_key)

#Configure Media Stack API
conn = http.client.HTTPConnection('api.mediastack.com')

# Configure Database Details
db_host = "127.0.0.1"
db_user = "root"
db_password = ""
db_name = "Mapolitical"

# Create a session object
session = requests.Session()
# Read parameters from CSV file
csv_file_path = 'mapolitical10.csv'
with open(csv_file_path, newline='') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    persons_data = list(csv_reader)

def filter_urls(initial_urls):
    filtered_urls = []
    for url in initial_urls:
        if any(ext in url for ext in ['.com', '.uk', '.co.uk', '.net', 'sports', 'sport']) or 'gov' in url or 'en.wikipedia.org' in url:
            filtered_urls.append(url)
    return filtered_urls

excluded_domains = ["facebook.com", "quora.com", "instagram.com", "twitter.com", "x.com", "linkedin.com", "usnews.com", "youtube.com", "imdb.com", "soundcloud.com", "tiktok.com", "amazon.co.uk", "amazon.com", "twinkl.co.uk", "amazon.in", "reddit.com", "ebay.com", "stackoverflow.com", "apple.com", "netflix.com", "flipkart.com", "nasa.gov"]    

# Connect to MySQL database
try:
    connection = mysql.connector.connect(
        host=db_host,
        user=db_user,
        password=db_password,
        database=db_name
    )
except mysql.connector.Error as err:
    print(f"Error: {err}")
    exit()

cursor = connection.cursor()

# Create tables if not exists
cursor.execute("""
    CREATE TABLE IF NOT EXISTS Person (
        id INT AUTO_INCREMENT PRIMARY KEY,
        name VARCHAR(255) NOT NULL,
        matching_pattern TEXT NOT NULL
    )
""")
cursor.execute("""
    CREATE TABLE IF NOT EXISTS RawData (
        id INT AUTO_INCREMENT PRIMARY KEY,
        person_id INT,
        url TEXT NOT NULL,
        title TEXT,
        body_text TEXT,
        FOREIGN KEY (person_id) REFERENCES Person (id)
    )
""")
connection.commit()

@retry(stop=stop_after_attempt(1), wait=wait_exponential(multiplier=1, max=4))
def analyze_website(url, person_id, combined_pattern, name):
    print(f"Confirming name: {name}")
    print("point 0")
    
    try:
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
        response = session.get(url, headers=headers, timeout=10)  # Add a timeout to the request
        response.raise_for_status()
    except requests.exceptions.Timeout:
        print(f"Timeout error for: {url}")
        return False, None
    except requests.exceptions.HTTPError as e:
        print(f"HTTP Error ({e.response.status_code}): {url}")
        return False, None
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return False, None

    # Introduce a delay of 1 second between requests to avoid being blocked
    sleep(1)
    
    print("point 1")
    
    # Check if the URL is a PDF using PyMuPDF
    try:
        with fitz.open("pdf", response.content):
            print(f"Skipping PDF: {url}")
            return False, None
    except Exception:
        pass

    # Check if the URL ends with a file extension to skip other file downloads
    file_extensions_to_skip = ['.pdf', '.doc', '.docx', '.ppt', '.pptx', '.xls', '.xlsx', '.ashx']
    
    if any(url.lower().endswith(extension) for extension in file_extensions_to_skip):
        print(f"Skipping file: {url}")
        return False, None
    
    soup = BeautifulSoup(response.content, "lxml")
    
    # Extract title or set a default as "no title" if not present
    title = soup.title.text if soup.title and soup.title.text else "No Title"
    print("point 2")
    
    # Extract specific elements or patterns from the body
    body_elements = soup.find_all(['p'])
    body_text = " ".join(element.get_text() for element in body_elements if not any(term in element.get_text().lower() for term in ['newsletter', 'cookie', 'Free shipping', 'order now', 'buy now', 'subscribe']))

    # Check for the presence of both person's name and keywords in the combined pattern
    person_name_found = name.lower() in body_text.lower()
    combined_pattern_found = re.search(combined_pattern, body_text, flags=re.IGNORECASE)

    # Check if both the person's name and keywords in the combined pattern are present in the scraped text
    if person_name_found or combined_pattern_found:
        # Return True if the relevant information is found
        return True, {"title": title, "body_text": body_text, "found_patterns": None}
    else:
        # Return False if either the person's name or combined pattern is not present
        print("Skipping URL as person's name or combined pattern not found in the scraped text")
        return False, None
    
# Process each person's data in the CSV file
for person_data in persons_data:
    
    # Set person-specific parameters
    person_name = person_data.get("name", "")
    tag1 = person_data.get("tag1", "")
    tag2 = person_data.get("tag2", "")
    tag3 = person_data.get("tag3", "")
    tag4 = person_data.get("tag4", "")
    tag5 = person_data.get("tag5", "")
    combined_pattern = person_data.get("combined_pattern", "")
    exactTerms = f"{person_name} {tag1}"
    matching_pattern = combined_pattern.replace('|', ',')
    
    print(f"Processing data for person: {person_name}")
   
    # Send search request and extract all URLs
    query = "{} {} {}".format(person_name,'politician', tag1)
    print(f"Query: {query}")
    
    filtered_urls = []
    
    excluded_domains = ["facebook.com", "quora.com", "instagram.com", "twitter.com", "x.com", "linkedin.com", "usnews.com", "youtube.com", "imdb.com", "soundcloud.com", "tiktok.com", "amazon.co.uk", "amazon.com", "twinkl.co.uk", "amazon.in", "reddit.com", "ebay.com", "stackoverflow.com", "apple.com", "netflix.com", "flipkart.com", "nasa.gov"]    
    
    url = "https://google-web-search1.p.rapidapi.com/"

    querystring = {"query": query, "limit": "300", "related_keywords": "true"}

    headers = {
        "X-RapidAPI-Key": "cdb75d5f93msh04a5483f73879fcp1ffcd9jsn299363ecf386",
        "X-RapidAPI-Host": "google-web-search1.p.rapidapi.com"
    }

    try:
        results = requests.get(url, headers=headers, params=querystring)
        results.raise_for_status()  # Check for request success

        # Parse the JSON response
        response_data = json.loads(results.text)

        # Extract URLs from the "results" key in the response_data
        results_list = response_data.get("results", [])
        current_page_urls = [result["url"] for result in results_list if all(excluded_domain not in urlparse(result["url"]).netloc for excluded_domain in excluded_domains)]

    except requests.exceptions.RequestException as e:
        print(f"Error making request to Google Web Search API: {e}")
        current_page_urls = []

    # Filter duplicate URLs
    filtered_urls = list(set(current_page_urls))

    print(f"Initial filtered URLs: {len(filtered_urls)}")
    print(f"Initial filtered URLs: {filtered_urls}")


#     print(f"DuckDuckgo API Starting Now")

#     # DuckDuckgo Search API
#     url = "https://duckduckgo10.p.rapidapi.com/search"
#     querystring = {"term": query,"safeSearch":"strict","region":"uk-en","offset":"100"}
#     headers = {
#         "X-RapidAPI-Key": "cdb75d5f93msh04a5483f73879fcp1ffcd9jsn299363ecf386",
#         "X-RapidAPI-Host": "duckduckgo10.p.rapidapi.com"
#         }

#     try:
#         response = requests.get(url, headers=headers, params=querystring)
#         response.raise_for_status()  # Check for request success

#         # Parse the JSON response
#         response_json = response.json()

#         # Check if the status is 200 (OK)
#         if response_json.get("status") == 200:
#             # Extract URLs from the "data" key in the response_json
#             results_list = response_json.get("data", [])
#             current_page_urls = [result["url"] for result in results_list if
#                                  all(excluded_domain not in urlparse(result["url"]).netloc for excluded_domain in excluded_domains)]

#             print(f"Current Page URLs received via DuckDuckGo Web Search API", current_page_urls)
#             print(f"Number of Current Page URLs received via DuckDuckGo Web Search API", {len(current_page_urls)})

#         else:
#             print("Error in DuckDuckGo Web Search API response:", response_json.get("message", "No message provided"))

#     except requests.exceptions.RequestException as e:
#         print(f"Error making request to DuckDuckGo Web Search API: {e}")
#         current_page_urls = []

#     filtered_urls = list(set(current_page_urls))
    
#     print(f"DuckDuckGo filtered URLs: {len(current_page_urls)}")

#     # Make a request to the Brave Search API
#     print(f"Brave Search API Starting Now")
    
#     url = "https://api.search.brave.com/res/v1/web/search"
#     querystring = {"q": query, "country": "GB", "search_lang": "en", "count": 20 }
#     headers = {
#         "Accept": "application/json",
#         "Accept-Encoding": "gzip",
#         "X-Subscription-Token": "BSAAalMwmfVxOCzd_jy6vyO-Ar8qpXR",  # Replace with your actual Brave Search API key
#     }

#     try:
#         response = requests.get(url, headers=headers, params=querystring)
#         response.raise_for_status()  # Check for request success

#         # Print the entire response content for debugging
#         print("Full API Response:", response.text)

#         # Parse the JSON response
#         response_json = response.json()

#         # Check if the response is successful
#         if response_json.get("type") == "search":
#             # Extract web results from the response_json
#             web_results = response_json.get("web", {}).get("results", [])

#             # Access specific fields based on your requirements
#             current_page_urls = [result.get("url", "") for result in web_results]
            
#             current_page_urls = [result["url"] for result in results_list if
#             all(excluded_domain not in urlparse(result["url"]).netloc for excluded_domain in excluded_domains)]

#             print("Web Results URLs:", current_page_urls)

#         else:
#             print("Error in Brave Web Search API response:", response_json.get("message", "No message provided"))

#     except requests.exceptions.RequestException as e:
#         print(f"Error making request to Brave Web Search API: {e}")
        
    filtered_urls = list(set(current_page_urls))
    
    print(f"Brave filtered URLs: {len(current_page_urls)}")

    filtered_urls = filter_urls(filtered_urls)

    print(f"Filtered URLs after domain extension, Wikipedia, and government link check: {len(filtered_urls)}")
    print(f"Filtered URLs after domain extension, Wikipedia, and government link check: {filtered_urls}")

    # Check if the person already exists in the Person table
    cursor.execute("SELECT id FROM Person WHERE name = %s", (person_name,))
    existing_person = cursor.fetchone()

    # If the person exists, fetch the ID; otherwise, insert the person into the Person table
    if existing_person:
        person_id = existing_person[0]
    else:
        cursor.execute("INSERT INTO Person (name, matching_pattern) VALUES (%s, %s)", (person_name, exactTerms))
        person_id = cursor.lastrowid

    print(f"Number of filtered URLs: {len(filtered_urls)}")

    # Scraping data from each URL in the list
    for key, url in enumerate(filtered_urls, start=1):
        print(f"Processing URL {key}/{len(filtered_urls)}: {url}")
        print(f"Confirming name: {person_name}")
        
        success, scraped_data = analyze_website(url, person_id, combined_pattern, person_name)
        print(success)
        if success:
            print("Scrape success for: " + url)
            # Check if the URL already exists in the RawData table
            cursor.execute("SELECT id FROM RawData WHERE url = %s", (url,))
            existing_data = cursor.fetchone()

            if existing_data:
                # If the URL exists, update the existing data
                cursor.execute("UPDATE RawData SET title = %s, body_text = %s WHERE id = %s",
                               (scraped_data.get("title", ""), scraped_data.get("body_text", ""), existing_data[0]))
                print(f"Updated data in the database for {person_name}")
            else:
                # If the URL doesn't exist, insert the scraped data into the RawData table
                cursor.execute("INSERT INTO RawData (person_id, url, title, body_text) VALUES (%s, %s, %s, %s)",
                               (person_id, url, scraped_data.get("title", ""), scraped_data.get("body_text", "")))
                print(f"Inserted data into the database for {person_name}")
        else:
            print("The URL is skipped")

    # Commit changes and close the connection
    connection.commit()

print("Scraping process completed")
connection.close()
# Out:
# Processing data for person: Daniel Zeichner
# Query: Daniel Zeichner politician biography
# Initial filtered URLs: 80
# Initial filtered URLs: ['https://bnnbreaking.com/world/uk/labours-green-energy-plans-spark-debate-over-future-of-rural-britain/', 'https://www.timesofisrael.com/jewish-conservatives-expected-to-sweep-their-constituencies-in-uk-general-elections/', 'https://www.wikiwand.com/en/Daniel%20Zeichner', 'https://www.museumofcambridge.org.uk/2021/05/daniel-zeichner-mp-to-officially-reopen-the-museum-of-cambridge/', 'https://vote.labour.org.uk/daniel-zeichner', 'https://www.parallelparliament.co.uk/mp/daniel-zeichner', 'https://www.indy100.com/politics/daniel-zeichner-sunak-elon-musk', 'https://downingplaceurc.org/daniel-zeichner-mp-visits-downing-place/', 'https://www.danielzeichner.co.uk/ministernew/', 'https://www.endsreport.com/article/1836472/whos-new-shadow-defra-team', 'https://www.cambridgelabour.org.uk/team/daniel-zeichner-mp/2020/05/21/', 'https://www.csap.cam.ac.uk/network/alex-mayer/', 'https://www.papworthtrust.org.uk/news-and-blogs/daniel-zeichner-mp-visits-cambridge-services/', 'https://www.huntspost.co.uk/news/23915043.cambridge-daniel-zeichner-says-foodbank-use-shameful/', 'https://fr.wikipedia.org/wiki/Daniel_Zeichner', 'https://vibmenis.info/kdultaipiezmcvj', 'https://www.theyworkforyou.com/mp/25386/daniel_zeichner/cambridge', 'https://www.huffingtonpost.co.uk/entry/pmqs-daniel-zeichner-says-brexit-labour-shortage-has-dealt-blow-to-great-british-pub_uk_59b91e38e4b086432b02e7a6', 'https://www.gbmc.org/provider/w-daniel-zeichner-md-anesthesiology', 'https://members.parliament.uk/member/4382/contact', 'https://www.longroad.ac.uk/', 'https://www.stmaryscambridge.co.uk/news-and-blog/view~daniel-zeichner-mp-visits-year-6_7711.htm', 'https://www.cambridgesu.co.uk/news/article/cambridgesu/Solidarity-with-the-Trans-Community-Update-from-Daniel-Zeichner-MP/', 'https://www.c-span.org/person/?100774/DanielZeichner', 'https://horizons.health/speaker/daniel-zeichner-mp/', 'https://peoplepill.com/people/daniel-zeichner', 'https://www.policyconnect.org.uk/people/daniel-zeichner-mp', 'https://www.theguardian.com/environment/2023/oct/17/labour-promises-end-badger-cull-england', 'https://triplydb.com/DBpedia-association/dbpedia/browser?resource=http%3A%2F%2Fdbpedia.org%2Fresource%2FDaniel_Zeichner', 'https://democracy.cambridge.gov.uk/mgUserInfo.aspx?UID=1353', 'https://www.howtopronounce.com/daniel-zeichner', 'https://www.longroad.ac.uk/page/?title=Politics+A+Level&pid=95', 'https://members.parliament.uk/member/4382/career', 'https://www.networkrailmediacentre.co.uk/news/cambridge-mp-daniel-zeichner-visits-site-of-new-gbp-50m-station', 'https://www.itv.com/news/anglia/2017-06-29/cambridge-mp-daniel-zeichner-resigns-from-shadow-cabinet-over-labours-brexit-policy', 'https://www.cambridgenetwork.co.uk/news/daniel-zeichner-visits-new-youth-project-aru', 'https://theparadise.ng/19648/how-every-mp-voted-on-the-rwanda-bill/', 'http://www.bonisonesproductions.com/lookingglass/index.html', 'https://www.mirror.co.uk/all-about/daniel-zeichner', 'https://www.varsity.co.uk/news/8145', 'https://www.elystandard.co.uk/news/23862673.mp-daniel-zeichner-demands-compensation-cambridgeshire/', 'https://www.city.ac.uk/__data/assets/pdf_file/0005/728942/CFS2023_contributor-bios.pdf', 'https://www.alzheimersresearchuk.org/blog/mp-daniel-zeichner-visits-alzheimers-research-uk/', 'https://www.cambridge-news.co.uk/all-about/daniel-zeichner', 'https://www.alamy.com/daniel-zeichner-mp-labour-cambridge-on-college-green-westminster-11th-april-2019-image243407520.html', 'https://www.wikilogy.com/biography/daniel-zeichner/', 'https://www.cambridge-news.co.uk/news/cambridge-news/cambridge-mp-daniel-zeichner-go-12514094', 'https://www.realself.com/dr/daniel-zeichner-fort-lauderdale-fl', 'https://www.parallelparliament.co.uk/mp/victoria-prentis/vs/daniel-zeichner', 'https://www.wikidata.org/wiki/Q20128211', 'https://www.newstatesman.com/politics/2017/09/cambridge-mp-daniel-zeichner-brexit-people-might-want-rethink', 'https://books.google.com/books?id=FOZtFgzPd5UC&pg=RA4- ...
# Brave filtered URLs: 80
# Filtered URLs after domain extension, Wikipedia, and government link check: 65
# Filtered URLs after domain extension, Wikipedia, and government link check: ['https://bnnbreaking.com/world/uk/labours-green-energy-plans-spark-debate-over-future-of-rural-britain/', 'https://www.timesofisrael.com/jewish-conservatives-expected-to-sweep-their-constituencies-in-uk-general-elections/', 'https://www.wikiwand.com/en/Daniel%20Zeichner', 'https://www.museumofcambridge.org.uk/2021/05/daniel-zeichner-mp-to-officially-reopen-the-museum-of-cambridge/', 'https://vote.labour.org.uk/daniel-zeichner', 'https://www.parallelparliament.co.uk/mp/daniel-zeichner', 'https://www.indy100.com/politics/daniel-zeichner-sunak-elon-musk', 'https://www.danielzeichner.co.uk/ministernew/', 'https://www.endsreport.com/article/1836472/whos-new-shadow-defra-team', 'https://www.cambridgelabour.org.uk/team/daniel-zeichner-mp/2020/05/21/', 'https://www.csap.cam.ac.uk/network/alex-mayer/', 'https://www.papworthtrust.org.uk/news-and-blogs/daniel-zeichner-mp-visits-cambridge-services/', 'https://www.huntspost.co.uk/news/23915043.cambridge-daniel-zeichner-says-foodbank-use-shameful/', 'https://www.theyworkforyou.com/mp/25386/daniel_zeichner/cambridge', 'https://www.huffingtonpost.co.uk/entry/pmqs-daniel-zeichner-says-brexit-labour-shortage-has-dealt-blow-to-great-british-pub_uk_59b91e38e4b086432b02e7a6', 'https://members.parliament.uk/member/4382/contact', 'https://www.longroad.ac.uk/', 'https://www.stmaryscambridge.co.uk/news-and-blog/view~daniel-zeichner-mp-visits-year-6_7711.htm', 'https://www.cambridgesu.co.uk/news/article/cambridgesu/Solidarity-with-the-Trans-Community-Update-from-Daniel-Zeichner-MP/', 'https://peoplepill.com/people/daniel-zeichner', 'https://www.policyconnect.org.uk/people/daniel-zeichner-mp', 'https://www.theguardian.com/environment/2023/oct/17/labour-promises-end-badger-cull-england', 'https://triplydb.com/DBpedia-association/dbpedia/browser?resource=http%3A%2F%2Fdbpedia.org%2Fresource%2FDaniel_Zeichner', 'https://democracy.cambridge.gov.uk/mgUserInfo.aspx?UID=1353', 'https://www.howtopronounce.com/daniel-zeichner', 'https://www.longroad.ac.uk/page/?title=Politics+A+Level&pid=95', 'https://members.parliament.uk/member/4382/career', 'https://www.networkrailmediacentre.co.uk/news/cambridge-mp-daniel-zeichner-visits-site-of-new-gbp-50m-station', 'https://www.itv.com/news/anglia/2017-06-29/cambridge-mp-daniel-zeichner-resigns-from-shadow-cabinet-over-labours-brexit-policy', 'https://www.cambridgenetwork.co.uk/news/daniel-zeichner-visits-new-youth-project-aru', 'http://www.bonisonesproductions.com/lookingglass/index.html', 'https://www.mirror.co.uk/all-about/daniel-zeichner', 'https://www.varsity.co.uk/news/8145', 'https://www.elystandard.co.uk/news/23862673.mp-daniel-zeichner-demands-compensation-cambridgeshire/', 'https://www.city.ac.uk/__data/assets/pdf_file/0005/728942/CFS2023_contributor-bios.pdf', 'https://www.cambridge-news.co.uk/all-about/daniel-zeichner', 'https://www.alamy.com/daniel-zeichner-mp-labour-cambridge-on-college-green-westminster-11th-april-2019-image243407520.html', 'https://www.wikilogy.com/biography/daniel-zeichner/', 'https://www.cambridge-news.co.uk/news/cambridge-news/cambridge-mp-daniel-zeichner-go-12514094', 'https://www.realself.com/dr/daniel-zeichner-fort-lauderdale-fl', 'https://www.parallelparliament.co.uk/mp/victoria-prentis/vs/daniel-zeichner', 'https://www.newstatesman.com/politics/2017/09/cambridge-mp-daniel-zeichner-brexit-people-might-want-rethink', 'https://books.google.com/books?id=FOZtFgzPd5UC&pg=RA4-PA154&lpg=RA4-PA154&dq=Daniel+Zeichner+politician+biography&source=bl&ots=JUhn49fBjQ&sig=ACfU3U0HpUhFT0ifMHYhIyrASXv0JRD93g&hl=en', 'https://www.metrobankonline.co.uk/about-us/press-releases/news/metro-daniel-zeichner-mp-visits-cambridge-bank/', 'https://www.anglianwater.co.uk/about-us/externalengagement/regionalengagement/what-do-our-stakeholders-say/', 'https://www.healthgrades.com/physician/dr-daniel-zeichner-yvj96', 'https://www.politics.co.uk/reference/daniel-zeichner/', 'https://allfamou ...
# Number of filtered URLs: 65
# Processing URL 1/65: https://bnnbreaking.com/world/uk/labours-green-energy-plans-spark-debate-over-future-of-rural-britain/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (502): https://bnnbreaking.com/world/uk/labours-green-energy-plans-spark-debate-over-future-of-rural-britain/
# False
# The URL is skipped
# Processing URL 2/65: https://www.timesofisrael.com/jewish-conservatives-expected-to-sweep-their-constituencies-in-uk-general-elections/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (403): https://www.timesofisrael.com/jewish-conservatives-expected-to-sweep-their-constituencies-in-uk-general-elections/
# False
# The URL is skipped
# Processing URL 3/65: https://www.wikiwand.com/en/Daniel%20Zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.wikiwand.com/en/Daniel%20Zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 4/65: https://www.museumofcambridge.org.uk/2021/05/daniel-zeichner-mp-to-officially-reopen-the-museum-of-cambridge/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.museumofcambridge.org.uk/2021/05/daniel-zeichner-mp-to-officially-reopen-the-museum-of-cambridge/
# Inserted data into the database for Daniel Zeichner
# Processing URL 5/65: https://vote.labour.org.uk/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://vote.labour.org.uk/daniel-zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 6/65: https://www.parallelparliament.co.uk/mp/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.parallelparliament.co.uk/mp/daniel-zeichner
# Updated data in the database for Daniel Zeichner
# Processing URL 7/65: https://www.indy100.com/politics/daniel-zeichner-sunak-elon-musk
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.indy100.com/politics/daniel-zeichner-sunak-elon-musk
# Inserted data into the database for Daniel Zeichner
# Processing URL 8/65: https://www.danielzeichner.co.uk/ministernew/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.danielzeichner.co.uk/ministernew/
# Inserted data into the database for Daniel Zeichner
# Processing URL 9/65: https://www.endsreport.com/article/1836472/whos-new-shadow-defra-team
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.endsreport.com/article/1836472/whos-new-shadow-defra-team
# Inserted data into the database for Daniel Zeichner
# Processing URL 10/65: https://www.cambridgelabour.org.uk/team/daniel-zeichner-mp/2020/05/21/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.cambridgelabour.org.uk/team/daniel-zeichner-mp/2020/05/21/
# Inserted data into the database for Daniel Zeichner
# Processing URL 11/65: https://www.csap.cam.ac.uk/network/alex-mayer/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.csap.cam.ac.uk/network/alex-mayer/
# Inserted data into the database for Daniel Zeichner
# Processing URL 12/65: https://www.papworthtrust.org.uk/news-and-blogs/daniel-zeichner-mp-visits-cambridge-services/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.papworthtrust.org.uk/news-and-blogs/daniel-zeichner-mp-visits-cambridge-services/
# Inserted data into the database for Daniel Zeichner
# Processing URL 13/65: https://www.huntspost.co.uk/news/23915043.cambridge-daniel-zeichner-says-foodbank-use-shameful/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.huntspost.co.uk/news/23915043.cambridge-daniel-zeichner-says-foodbank-use-shameful/
# Inserted data into the database for Daniel Zeichner
# Processing URL 14/65: https://www.theyworkforyou.com/mp/25386/daniel_zeichner/cambridge
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (503): https://www.theyworkforyou.com/mp/25386/daniel_zeichner/cambridge
# False
# The URL is skipped
# Processing URL 15/65: https://www.huffingtonpost.co.uk/entry/pmqs-daniel-zeichner-says-brexit-labour-shortage-has-dealt-blow-to-great-british-pub_uk_59b91e38e4b086432b02e7a6
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.huffingtonpost.co.uk/entry/pmqs-daniel-zeichner-says-brexit-labour-shortage-has-dealt-blow-to-great-british-pub_uk_59b91e38e4b086432b02e7a6
# Inserted data into the database for Daniel Zeichner
# Processing URL 16/65: https://members.parliament.uk/member/4382/contact
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (403): https://members.parliament.uk/member/4382/contact
# False
# The URL is skipped
# Processing URL 17/65: https://www.longroad.ac.uk/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.longroad.ac.uk/
# Inserted data into the database for Daniel Zeichner
# Processing URL 18/65: https://www.stmaryscambridge.co.uk/news-and-blog/view~daniel-zeichner-mp-visits-year-6_7711.htm
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.stmaryscambridge.co.uk/news-and-blog/view~daniel-zeichner-mp-visits-year-6_7711.htm
# Inserted data into the database for Daniel Zeichner
# Processing URL 19/65: https://www.cambridgesu.co.uk/news/article/cambridgesu/Solidarity-with-the-Trans-Community-Update-from-Daniel-Zeichner-MP/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.cambridgesu.co.uk/news/article/cambridgesu/Solidarity-with-the-Trans-Community-Update-from-Daniel-Zeichner-MP/
# Inserted data into the database for Daniel Zeichner
# Processing URL 20/65: https://peoplepill.com/people/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://peoplepill.com/people/daniel-zeichner
# Updated data in the database for Daniel Zeichner
# Processing URL 21/65: https://www.policyconnect.org.uk/people/daniel-zeichner-mp
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.policyconnect.org.uk/people/daniel-zeichner-mp
# Inserted data into the database for Daniel Zeichner
# Processing URL 22/65: https://www.theguardian.com/environment/2023/oct/17/labour-promises-end-badger-cull-england
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.theguardian.com/environment/2023/oct/17/labour-promises-end-badger-cull-england
# Inserted data into the database for Daniel Zeichner
# Processing URL 23/65: https://triplydb.com/DBpedia-association/dbpedia/browser?resource=http%3A%2F%2Fdbpedia.org%2Fresource%2FDaniel_Zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://triplydb.com/DBpedia-association/dbpedia/browser?resource=http%3A%2F%2Fdbpedia.org%2Fresource%2FDaniel_Zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 24/65: https://democracy.cambridge.gov.uk/mgUserInfo.aspx?UID=1353
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://democracy.cambridge.gov.uk/mgUserInfo.aspx?UID=1353
# Inserted data into the database for Daniel Zeichner
# Processing URL 25/65: https://www.howtopronounce.com/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.howtopronounce.com/daniel-zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 26/65: https://www.longroad.ac.uk/page/?title=Politics+A+Level&pid=95
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.longroad.ac.uk/page/?title=Politics+A+Level&pid=95
# Inserted data into the database for Daniel Zeichner
# Processing URL 27/65: https://members.parliament.uk/member/4382/career
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (403): https://members.parliament.uk/member/4382/career
# False
# The URL is skipped
# Processing URL 28/65: https://www.networkrailmediacentre.co.uk/news/cambridge-mp-daniel-zeichner-visits-site-of-new-gbp-50m-station
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.networkrailmediacentre.co.uk/news/cambridge-mp-daniel-zeichner-visits-site-of-new-gbp-50m-station
# Inserted data into the database for Daniel Zeichner
# Processing URL 29/65: https://www.itv.com/news/anglia/2017-06-29/cambridge-mp-daniel-zeichner-resigns-from-shadow-cabinet-over-labours-brexit-policy
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.itv.com/news/anglia/2017-06-29/cambridge-mp-daniel-zeichner-resigns-from-shadow-cabinet-over-labours-brexit-policy
# Inserted data into the database for Daniel Zeichner
# Processing URL 30/65: https://www.cambridgenetwork.co.uk/news/daniel-zeichner-visits-new-youth-project-aru
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.cambridgenetwork.co.uk/news/daniel-zeichner-visits-new-youth-project-aru
# Inserted data into the database for Daniel Zeichner
# Processing URL 31/65: http://www.bonisonesproductions.com/lookingglass/index.html
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: http://www.bonisonesproductions.com/lookingglass/index.html
# Updated data in the database for Daniel Zeichner
# Processing URL 32/65: https://www.mirror.co.uk/all-about/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.mirror.co.uk/all-about/daniel-zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 33/65: https://www.varsity.co.uk/news/8145
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.varsity.co.uk/news/8145
# Inserted data into the database for Daniel Zeichner
# Processing URL 34/65: https://www.elystandard.co.uk/news/23862673.mp-daniel-zeichner-demands-compensation-cambridgeshire/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.elystandard.co.uk/news/23862673.mp-daniel-zeichner-demands-compensation-cambridgeshire/
# Inserted data into the database for Daniel Zeichner
# Processing URL 35/65: https://www.city.ac.uk/__data/assets/pdf_file/0005/728942/CFS2023_contributor-bios.pdf
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# Skipping PDF: https://www.city.ac.uk/__data/assets/pdf_file/0005/728942/CFS2023_contributor-bios.pdf
# False
# The URL is skipped
# Processing URL 36/65: https://www.cambridge-news.co.uk/all-about/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.cambridge-news.co.uk/all-about/daniel-zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 37/65: https://www.alamy.com/daniel-zeichner-mp-labour-cambridge-on-college-green-westminster-11th-april-2019-image243407520.html
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# Skipping PDF: https://www.alamy.com/daniel-zeichner-mp-labour-cambridge-on-college-green-westminster-11th-april-2019-image243407520.html
# False
# The URL is skipped
# Processing URL 38/65: https://www.wikilogy.com/biography/daniel-zeichner/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.wikilogy.com/biography/daniel-zeichner/
# Inserted data into the database for Daniel Zeichner
# Processing URL 39/65: https://www.cambridge-news.co.uk/news/cambridge-news/cambridge-mp-daniel-zeichner-go-12514094
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.cambridge-news.co.uk/news/cambridge-news/cambridge-mp-daniel-zeichner-go-12514094
# Inserted data into the database for Daniel Zeichner
# Processing URL 40/65: https://www.realself.com/dr/daniel-zeichner-fort-lauderdale-fl
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (403): https://www.realself.com/dr/daniel-zeichner-fort-lauderdale-fl
# False
# The URL is skipped
# Processing URL 41/65: https://www.parallelparliament.co.uk/mp/victoria-prentis/vs/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.parallelparliament.co.uk/mp/victoria-prentis/vs/daniel-zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 42/65: https://www.newstatesman.com/politics/2017/09/cambridge-mp-daniel-zeichner-brexit-people-might-want-rethink
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.newstatesman.com/politics/2017/09/cambridge-mp-daniel-zeichner-brexit-people-might-want-rethink
# Inserted data into the database for Daniel Zeichner
# Processing URL 43/65: https://books.google.com/books?id=FOZtFgzPd5UC&pg=RA4-PA154&lpg=RA4-PA154&dq=Daniel+Zeichner+politician+biography&source=bl&ots=JUhn49fBjQ&sig=ACfU3U0HpUhFT0ifMHYhIyrASXv0JRD93g&hl=en
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://books.google.com/books?id=FOZtFgzPd5UC&pg=RA4-PA154&lpg=RA4-PA154&dq=Daniel+Zeichner+politician+biography&source=bl&ots=JUhn49fBjQ&sig=ACfU3U0HpUhFT0ifMHYhIyrASXv0JRD93g&hl=en
# Inserted data into the database for Daniel Zeichner
# Processing URL 44/65: https://www.metrobankonline.co.uk/about-us/press-releases/news/metro-daniel-zeichner-mp-visits-cambridge-bank/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.metrobankonline.co.uk/about-us/press-releases/news/metro-daniel-zeichner-mp-visits-cambridge-bank/
# Inserted data into the database for Daniel Zeichner
# Processing URL 45/65: https://www.anglianwater.co.uk/about-us/externalengagement/regionalengagement/what-do-our-stakeholders-say/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.anglianwater.co.uk/about-us/externalengagement/regionalengagement/what-do-our-stakeholders-say/
# Inserted data into the database for Daniel Zeichner
# Processing URL 46/65: https://www.healthgrades.com/physician/dr-daniel-zeichner-yvj96
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (403): https://www.healthgrades.com/physician/dr-daniel-zeichner-yvj96
# False
# The URL is skipped
# Processing URL 47/65: https://www.politics.co.uk/reference/daniel-zeichner/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (403): https://www.politics.co.uk/reference/daniel-zeichner/
# False
# The URL is skipped
# Processing URL 48/65: https://allfamousbirthday.com/daniel-zeichner/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://allfamousbirthday.com/daniel-zeichner/
# Updated data in the database for Daniel Zeichner
# Processing URL 49/65: https://www.cser.ac.uk/news/cambridge-students-join-forces-mps-launch-appg-com/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.cser.ac.uk/news/cambridge-students-join-forces-mps-launch-appg-com/
# Inserted data into the database for Daniel Zeichner
# Processing URL 50/65: https://www.varsity.co.uk/interviews/18333
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.varsity.co.uk/interviews/18333
# Inserted data into the database for Daniel Zeichner
# Processing URL 51/65: https://cambridgetownowl.com/2021/02/02/cambridge-mp-daniel-zeichner-tears-into-the-house-building-industry-over-poor-building-standards/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://cambridgetownowl.com/2021/02/02/cambridge-mp-daniel-zeichner-tears-into-the-house-building-industry-over-poor-building-standards/
# Inserted data into the database for Daniel Zeichner
# Processing URL 52/65: https://groundswellag.com/speakers/daniel-zeichner-mp/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://groundswellag.com/speakers/daniel-zeichner-mp/
# Inserted data into the database for Daniel Zeichner
# Processing URL 53/65: https://www.huffingtonpost.co.uk/author/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.huffingtonpost.co.uk/author/daniel-zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 54/65: https://xampla.com/daniel-zeichner-mp-visits-lab/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://xampla.com/daniel-zeichner-mp-visits-lab/
# Updated data in the database for Daniel Zeichner
# Processing URL 55/65: http://www.eng.cam.ac.uk/news/cambridge-climate-lecture-series-0
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: http://www.eng.cam.ac.uk/news/cambridge-climate-lecture-series-0
# Updated data in the database for Daniel Zeichner
# Processing URL 56/65: https://www.danielzeichner.co.uk/about/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.danielzeichner.co.uk/about/
# Updated data in the database for Daniel Zeichner
# Processing URL 57/65: https://www.cambridgeshirechamber.co.uk/cambridge/lsip-attend-the-innovate-cambridge-summit-2023/
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.cambridgeshirechamber.co.uk/cambridge/lsip-attend-the-innovate-cambridge-summit-2023/
# Inserted data into the database for Daniel Zeichner
# Processing URL 58/65: https://www.theyworkforyou.com/mp/25386/daniel_zeichner/cambridge/votes
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# HTTP Error (503): https://www.theyworkforyou.com/mp/25386/daniel_zeichner/cambridge/votes
# False
# The URL is skipped
# Processing URL 59/65: https://whocanivotefor.co.uk/person/45/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://whocanivotefor.co.uk/person/45/daniel-zeichner
# Inserted data into the database for Daniel Zeichner
# Processing URL 60/65: https://climateseries.com/lectures/ccls2023/115-climate-uk-politics
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# Error fetching https://climateseries.com/lectures/ccls2023/115-climate-uk-politics: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# False
# The URL is skipped
# Processing URL 61/65: https://www.cambridgenetwork.co.uk/directories/companies/3455
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.cambridgenetwork.co.uk/directories/companies/3455
# Inserted data into the database for Daniel Zeichner
# Processing URL 62/65: https://en.wikipedia.org/wiki/Daniel_Zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://en.wikipedia.org/wiki/Daniel_Zeichner
# Updated data in the database for Daniel Zeichner
# Processing URL 63/65: https://www.hortweek.com/labour-party-horticulture-elected-shadow-defra-minister-daniel-zeichner-answers/fresh-produce/article/1802878
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.hortweek.com/labour-party-horticulture-elected-shadow-defra-minister-daniel-zeichner-answers/fresh-produce/article/1802878
# Inserted data into the database for Daniel Zeichner
# Processing URL 64/65: https://www.bbc.com/news/uk-england-cambridgeshire-68023157
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.bbc.com/news/uk-england-cambridgeshire-68023157
# Inserted data into the database for Daniel Zeichner
# Processing URL 65/65: https://policymogul.com/stakeholders/12668/daniel-zeichner
# Confirming name: Daniel Zeichner
# Confirming name: Daniel Zeichner
# point 0
# point 1
# point 2
# True
# Scrape success for: https://policymogul.com/stakeholders/12668/daniel-zeichner
# Inserted data into the database for Daniel Zeichner
# Processing data for person: Rishi Sunak
# Query: Rishi Sunak politician biography
# Initial filtered URLs: 173
# Initial filtered URLs: ['https://www.mapsofindia.com/my-india/politics/who-is-rishi-sunak-2', 'https://indianexpress.com/article/explained/who-is-rishi-sunak-the-indian-origin-leader-campaigning-to-become-uks-prime-minister-8019385/', 'https://www.standard.co.uk/lifestyle/rishi-sunak-prime-minister-wealth-wife-brexit-personal-life-policies-wealth-b1012314.html', 'https://www.dailynewsreport.com.ng/2023/03/biography-of-uk-prime-minister-rishi.html', 'https://www.whitehouse.gov/briefing-room/statements-releases/2023/10/30/fact-sheet-president-biden-issues-executive-order-on-safe-secure-and-trustworthy-artificial-intelligence/', 'https://www.france24.com/en/europe/20221024-rishi-sunak-young-ultra-rich-and-uk-s-first-pm-of-colour', 'https://www.investopedia.com/who-is-rishi-sunak-6822837', 'https://www.japantimes.co.jp/news/2023/10/06/world/politics/sunak-makeover-indian-heritage/', 'https://www.spectator.co.uk/article/what-lee-andersons-resignation-means-for-rishi-sunak/', 'https://www.newstatesman.com/', 'https://apnews.com/article/british-politics-health-rishi-sunak-europe-business-2accaf1a5cf58d10fc5517e10ffe7d9c', 'https://asia.nikkei.com/Politics/Indians-laud-Rishi-Sunak-becoming-U.K.-s-first-nonwhite-PM', 'http://katiecouric.com/news/who-is-rishi-sunak-britains-new-prime-minister/', 'https://www.independent.co.uk/news/uk/politics/rishi-sunak-family-wife-net-worth-general-election-b2214057.html', 'https://www.atlanticcouncil.org/blogs/new-atlanticist/experts-react-rishi-sunak-makes-history-as-newest-uk-prime-minister-can-he-calm-a-country-in-chaos/', 'https://www.fresherslive.com/latest/articles/who-are-rishi-sunak-parents-where-is-rishi-sunak-parents-from-what-is-rishi-sunak-parents-nationality-10017699', 'https://newsnownigeria.ng/rishi-sunak-age-uk-prime-minister-net-worth-wiki-family-biography-and-latest-updates/', 'https://short-biography.com/rishi-sunak.htm', 'https://spongefan.fandom.com/wiki/Rishi_Sunak', 'https://bbc.dpver.gov.ar/en/prime-minister-age/', 'https://www.aston.ac.uk/latest-news/podcast-uks-first-non-white-prime-minister-big-moment-can-rishi-sunak-survive', 'https://www.business-standard.com/about/who-is-rishi-sunak', 'https://peoplepill.com/i/rishi-sunak', 'https://uk.advfn.com/stock-market/share-news/New-Book-by-Michael-Ashcroft-Red-Queen-The-Unauth/93094268', 'https://www.findmypast.com/blog/discoveries/rishi-sunak-family-tree', 'https://www.timesofisrael.com/israels-newest-british-born-international-spokesperson-is-raising-some-eyebrows/', 'https://www.politico.eu/newsletter/london-playbook/london-playbook-pm-lords-flex-on-rwanda/', 'https://www.onthisday.com/people/rishi-sunak', 'https://finance.yahoo.com/news/play-advance-rishi-sunak-michael-060000001.html', 'https://www.who2.com/bio/rishi-sunak/', 'https://www.jagranjosh.com/general-knowledge/rishi-sunak-biography-1642162759-1', 'https://medium.com/@i.amAshu/rishi-sunak-biography-will-he-be-the-next-prime-minister-of-the-uk-2a8c5e8499dd', 'https://www.livemint.com/news/world/explained-how-rishi-sunak-is-connected-with-both-india-and-pakistan-11666756704160.html', 'https://davidcoletto.substack.com/p/can-trudeau-win-in-2025-i-dont-think', 'https://abcnews.go.com/International/rishi-sunak-chosen-british-prime-minister/story?id=91998128', 'https://www.aa.com.tr/en/africa/east-africans-react-to-rishi-sunak-becoming-uk-prime-minister/2720749', 'https://www.cbsnews.com/news/rishi-sunak-new-uk-prime-minister-wealth-richer-than-queen-elizabeth/', 'https://www.cnn.com/2023/09/09/uk/rishi-sunak-autumn-reset-intl-gbr-cmd/index.html', 'https://www.studysmarter.co.uk/explanations/politics/uk-government/rishi-sunak/', 'https://globaleng.biz/person/id/6', 'https://www.conservatives.com/', 'https://m.economictimes.com/news/international/uk/rishi-sunak-know-uk-pms-birth-age-parents-education-political-career-net-worth/articleshow/95082492.cms', 'https://books.google.com/books/about/Rishi_Sunak.html?id=0fpLzwEACAAJ', 'https://www.indiatoday.in/world/story/rishi-sun ...
# Brave filtered URLs: 173
# Filtered URLs after domain extension, Wikipedia, and government link check: 141
# Filtered URLs after domain extension, Wikipedia, and government link check: ['https://www.mapsofindia.com/my-india/politics/who-is-rishi-sunak-2', 'https://indianexpress.com/article/explained/who-is-rishi-sunak-the-indian-origin-leader-campaigning-to-become-uks-prime-minister-8019385/', 'https://www.standard.co.uk/lifestyle/rishi-sunak-prime-minister-wealth-wife-brexit-personal-life-policies-wealth-b1012314.html', 'https://www.dailynewsreport.com.ng/2023/03/biography-of-uk-prime-minister-rishi.html', 'https://www.whitehouse.gov/briefing-room/statements-releases/2023/10/30/fact-sheet-president-biden-issues-executive-order-on-safe-secure-and-trustworthy-artificial-intelligence/', 'https://www.france24.com/en/europe/20221024-rishi-sunak-young-ultra-rich-and-uk-s-first-pm-of-colour', 'https://www.investopedia.com/who-is-rishi-sunak-6822837', 'https://www.spectator.co.uk/article/what-lee-andersons-resignation-means-for-rishi-sunak/', 'https://www.newstatesman.com/', 'https://apnews.com/article/british-politics-health-rishi-sunak-europe-business-2accaf1a5cf58d10fc5517e10ffe7d9c', 'https://asia.nikkei.com/Politics/Indians-laud-Rishi-Sunak-becoming-U.K.-s-first-nonwhite-PM', 'http://katiecouric.com/news/who-is-rishi-sunak-britains-new-prime-minister/', 'https://www.independent.co.uk/news/uk/politics/rishi-sunak-family-wife-net-worth-general-election-b2214057.html', 'https://www.fresherslive.com/latest/articles/who-are-rishi-sunak-parents-where-is-rishi-sunak-parents-from-what-is-rishi-sunak-parents-nationality-10017699', 'https://short-biography.com/rishi-sunak.htm', 'https://spongefan.fandom.com/wiki/Rishi_Sunak', 'https://bbc.dpver.gov.ar/en/prime-minister-age/', 'https://www.aston.ac.uk/latest-news/podcast-uks-first-non-white-prime-minister-big-moment-can-rishi-sunak-survive', 'https://www.business-standard.com/about/who-is-rishi-sunak', 'https://peoplepill.com/i/rishi-sunak', 'https://uk.advfn.com/stock-market/share-news/New-Book-by-Michael-Ashcroft-Red-Queen-The-Unauth/93094268', 'https://www.findmypast.com/blog/discoveries/rishi-sunak-family-tree', 'https://www.timesofisrael.com/israels-newest-british-born-international-spokesperson-is-raising-some-eyebrows/', 'https://www.onthisday.com/people/rishi-sunak', 'https://finance.yahoo.com/news/play-advance-rishi-sunak-michael-060000001.html', 'https://www.who2.com/bio/rishi-sunak/', 'https://www.jagranjosh.com/general-knowledge/rishi-sunak-biography-1642162759-1', 'https://medium.com/@i.amAshu/rishi-sunak-biography-will-he-be-the-next-prime-minister-of-the-uk-2a8c5e8499dd', 'https://www.livemint.com/news/world/explained-how-rishi-sunak-is-connected-with-both-india-and-pakistan-11666756704160.html', 'https://davidcoletto.substack.com/p/can-trudeau-win-in-2025-i-dont-think', 'https://abcnews.go.com/International/rishi-sunak-chosen-british-prime-minister/story?id=91998128', 'https://www.aa.com.tr/en/africa/east-africans-react-to-rishi-sunak-becoming-uk-prime-minister/2720749', 'https://www.cbsnews.com/news/rishi-sunak-new-uk-prime-minister-wealth-richer-than-queen-elizabeth/', 'https://www.cnn.com/2023/09/09/uk/rishi-sunak-autumn-reset-intl-gbr-cmd/index.html', 'https://www.studysmarter.co.uk/explanations/politics/uk-government/rishi-sunak/', 'https://www.conservatives.com/', 'https://m.economictimes.com/news/international/uk/rishi-sunak-know-uk-pms-birth-age-parents-education-political-career-net-worth/articleshow/95082492.cms', 'https://books.google.com/books/about/Rishi_Sunak.html?id=0fpLzwEACAAJ', 'https://www.express.co.uk/news/politics/1359852/Rishi-Sunak-chancellor-of-the-exchequer-new-biography-hedge-funds-tory-mp', 'https://www.thequint.com/news/world/mp-to-uks-first-desi-pm-timeline-of-key-events-that-led-to-rishi-sunak-creating-history-indian-origin-non-white-pm', 'https://www.cnn.com/2022/10/24/uk/profile-rishi-sunak-uk-politics-intl-gbr/index.html', 'https://www.bitebackpublishing.com/books/all-to-play-for', 'https://www.lbc.co.uk/', 'https://www.theguardian.com/politics/20 ...
# Number of filtered URLs: 141
# Processing URL 1/141: https://www.mapsofindia.com/my-india/politics/who-is-rishi-sunak-2
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# HTTP Error (403): https://www.mapsofindia.com/my-india/politics/who-is-rishi-sunak-2
# False
# The URL is skipped
# Processing URL 2/141: https://indianexpress.com/article/explained/who-is-rishi-sunak-the-indian-origin-leader-campaigning-to-become-uks-prime-minister-8019385/
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://indianexpress.com/article/explained/who-is-rishi-sunak-the-indian-origin-leader-campaigning-to-become-uks-prime-minister-8019385/
# Inserted data into the database for Rishi Sunak
# Processing URL 3/141: https://www.standard.co.uk/lifestyle/rishi-sunak-prime-minister-wealth-wife-brexit-personal-life-policies-wealth-b1012314.html
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.standard.co.uk/lifestyle/rishi-sunak-prime-minister-wealth-wife-brexit-personal-life-policies-wealth-b1012314.html
# Inserted data into the database for Rishi Sunak
# Processing URL 4/141: https://www.dailynewsreport.com.ng/2023/03/biography-of-uk-prime-minister-rishi.html
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# Skipping URL as person's name or combined pattern not found in the scraped text
# False
# The URL is skipped
# Processing URL 5/141: https://www.whitehouse.gov/briefing-room/statements-releases/2023/10/30/fact-sheet-president-biden-issues-executive-order-on-safe-secure-and-trustworthy-artificial-intelligence/
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.whitehouse.gov/briefing-room/statements-releases/2023/10/30/fact-sheet-president-biden-issues-executive-order-on-safe-secure-and-trustworthy-artificial-intelligence/
# Inserted data into the database for Rishi Sunak
# Processing URL 6/141: https://www.france24.com/en/europe/20221024-rishi-sunak-young-ultra-rich-and-uk-s-first-pm-of-colour
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.france24.com/en/europe/20221024-rishi-sunak-young-ultra-rich-and-uk-s-first-pm-of-colour
# Inserted data into the database for Rishi Sunak
# Processing URL 7/141: https://www.investopedia.com/who-is-rishi-sunak-6822837
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.investopedia.com/who-is-rishi-sunak-6822837
# Updated data in the database for Rishi Sunak
# Processing URL 8/141: https://www.spectator.co.uk/article/what-lee-andersons-resignation-means-for-rishi-sunak/
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.spectator.co.uk/article/what-lee-andersons-resignation-means-for-rishi-sunak/
# Updated data in the database for Rishi Sunak
# Processing URL 9/141: https://www.newstatesman.com/
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# Skipping URL as person's name or combined pattern not found in the scraped text
# False
# The URL is skipped
# Processing URL 10/141: https://apnews.com/article/british-politics-health-rishi-sunak-europe-business-2accaf1a5cf58d10fc5517e10ffe7d9c
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://apnews.com/article/british-politics-health-rishi-sunak-europe-business-2accaf1a5cf58d10fc5517e10ffe7d9c
# Inserted data into the database for Rishi Sunak
# Processing URL 11/141: https://asia.nikkei.com/Politics/Indians-laud-Rishi-Sunak-becoming-U.K.-s-first-nonwhite-PM
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://asia.nikkei.com/Politics/Indians-laud-Rishi-Sunak-becoming-U.K.-s-first-nonwhite-PM
# Inserted data into the database for Rishi Sunak
# Processing URL 12/141: http://katiecouric.com/news/who-is-rishi-sunak-britains-new-prime-minister/
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: http://katiecouric.com/news/who-is-rishi-sunak-britains-new-prime-minister/
# Inserted data into the database for Rishi Sunak
# Processing URL 13/141: https://www.independent.co.uk/news/uk/politics/rishi-sunak-family-wife-net-worth-general-election-b2214057.html
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.independent.co.uk/news/uk/politics/rishi-sunak-family-wife-net-worth-general-election-b2214057.html
# Inserted data into the database for Rishi Sunak
# Processing URL 14/141: https://www.fresherslive.com/latest/articles/who-are-rishi-sunak-parents-where-is-rishi-sunak-parents-from-what-is-rishi-sunak-parents-nationality-10017699
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.fresherslive.com/latest/articles/who-are-rishi-sunak-parents-where-is-rishi-sunak-parents-from-what-is-rishi-sunak-parents-nationality-10017699
# Updated data in the database for Rishi Sunak
# Processing URL 15/141: https://short-biography.com/rishi-sunak.htm
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://short-biography.com/rishi-sunak.htm
# Updated data in the database for Rishi Sunak
# Processing URL 16/141: https://spongefan.fandom.com/wiki/Rishi_Sunak
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://spongefan.fandom.com/wiki/Rishi_Sunak
# Inserted data into the database for Rishi Sunak
# Processing URL 17/141: https://bbc.dpver.gov.ar/en/prime-minister-age/
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://bbc.dpver.gov.ar/en/prime-minister-age/
# Updated data in the database for Rishi Sunak
# Processing URL 18/141: https://www.aston.ac.uk/latest-news/podcast-uks-first-non-white-prime-minister-big-moment-can-rishi-sunak-survive
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.aston.ac.uk/latest-news/podcast-uks-first-non-white-prime-minister-big-moment-can-rishi-sunak-survive
# Inserted data into the database for Rishi Sunak
# Processing URL 19/141: https://www.business-standard.com/about/who-is-rishi-sunak
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# HTTP Error (403): https://www.business-standard.com/about/who-is-rishi-sunak
# False
# The URL is skipped
# Processing URL 20/141: https://peoplepill.com/i/rishi-sunak
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://peoplepill.com/i/rishi-sunak
# Inserted data into the database for Rishi Sunak
# Processing URL 21/141: https://uk.advfn.com/stock-market/share-news/New-Book-by-Michael-Ashcroft-Red-Queen-The-Unauth/93094268
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://uk.advfn.com/stock-market/share-news/New-Book-by-Michael-Ashcroft-Red-Queen-The-Unauth/93094268
# Updated data in the database for Rishi Sunak
# Processing URL 22/141: https://www.findmypast.com/blog/discoveries/rishi-sunak-family-tree
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.findmypast.com/blog/discoveries/rishi-sunak-family-tree
# Inserted data into the database for Rishi Sunak
# Processing URL 23/141: https://www.timesofisrael.com/israels-newest-british-born-international-spokesperson-is-raising-some-eyebrows/
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# HTTP Error (403): https://www.timesofisrael.com/israels-newest-british-born-international-spokesperson-is-raising-some-eyebrows/
# False
# The URL is skipped
# Processing URL 24/141: https://www.onthisday.com/people/rishi-sunak
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.onthisday.com/people/rishi-sunak
# Inserted data into the database for Rishi Sunak
# Processing URL 25/141: https://finance.yahoo.com/news/play-advance-rishi-sunak-michael-060000001.html
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://finance.yahoo.com/news/play-advance-rishi-sunak-michael-060000001.html
# Inserted data into the database for Rishi Sunak
# Processing URL 26/141: https://www.who2.com/bio/rishi-sunak/
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.who2.com/bio/rishi-sunak/
# Updated data in the database for Rishi Sunak
# Processing URL 27/141: https://www.jagranjosh.com/general-knowledge/rishi-sunak-biography-1642162759-1
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.jagranjosh.com/general-knowledge/rishi-sunak-biography-1642162759-1
# Updated data in the database for Rishi Sunak
# Processing URL 28/141: https://medium.com/@i.amAshu/rishi-sunak-biography-will-he-be-the-next-prime-minister-of-the-uk-2a8c5e8499dd
# Confirming name: Rishi Sunak
# Confirming name: Rishi Sunak
# point 0
# point 1
# point 2
# True
# Scrape success for: https://medium.com/@i.amAshu/rishi-sunak-biography-will-he-be-the-next-prime-minister-of-the-uk-2a8c5e8499dd
# Inserted data into the database for Rishi Sunak
# Processing URL 29/141: https://www.livemint.com/news/world/explained-how-rishi-sunak-is-connected-with-both-india-and-pakistan-11666756704160.html
# Confirming name: Rishi Sunak
# ...
# Scrape success for: https://www.bloomberg.com/news/articles/2024-01-22/sunak-says-jeremy-hunt-will-be-uk-chancellor-at-general-election
# Inserted data into the database for Jeremy Hunt
# Processing URL 70/116: https://yougov.co.uk/topics/politics/explore/public_figure/Jeremy_Hunt
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://yougov.co.uk/topics/politics/explore/public_figure/Jeremy_Hunt
# Inserted data into the database for Jeremy Hunt
# Processing URL 71/116: https://www.the-sun.com/news/5772838/jeremy-hunt-wife-lucia-guo/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.the-sun.com/news/5772838/jeremy-hunt-wife-lucia-guo/
# Inserted data into the database for Jeremy Hunt
# Processing URL 72/116: https://www.wikiwand.com/simple/Jeremy_Hunt
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.wikiwand.com/simple/Jeremy_Hunt
# Inserted data into the database for Jeremy Hunt
# Processing URL 73/116: https://www.wsj.com/articles/new-u-k-chancellor-jeremy-hunt-seen-as-moderate-in-bid-to-appease-markets-11665771235
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# HTTP Error (401): https://www.wsj.com/articles/new-u-k-chancellor-jeremy-hunt-seen-as-moderate-in-bid-to-appease-markets-11665771235
# False
# The URL is skipped
# Processing URL 74/116: https://books.google.com/books?id=EvlcvuLGq7wC&pg=RA1-PA11&lpg=RA1-PA11&dq=Jeremy+Hunt+politician+biography&source=bl&ots=j1wbKHn6mK&sig=ACfU3U1m-e2FinxH-JI-pcG0CvViZUyWww&hl=en
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://books.google.com/books?id=EvlcvuLGq7wC&pg=RA1-PA11&lpg=RA1-PA11&dq=Jeremy+Hunt+politician+biography&source=bl&ots=j1wbKHn6mK&sig=ACfU3U1m-e2FinxH-JI-pcG0CvViZUyWww&hl=en
# Inserted data into the database for Jeremy Hunt
# Processing URL 75/116: https://www.newyorker.com/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.newyorker.com/
# Inserted data into the database for Jeremy Hunt
# Processing URL 76/116: https://dehavilland-web-data-9w52go.s3.eu-west-2.amazonaws.com/PoliticalUploads/2022/TrussReshuffle/JeremyHuntCX.pdf
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# Skipping PDF: https://dehavilland-web-data-9w52go.s3.eu-west-2.amazonaws.com/PoliticalUploads/2022/TrussReshuffle/JeremyHuntCX.pdf
# False
# The URL is skipped
# Processing URL 77/116: https://www.bloomberg.com/news/articles/2023-10-21/chancellor-jeremy-hunt-won-t-quit-parliament-before-election
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.bloomberg.com/news/articles/2023-10-21/chancellor-jeremy-hunt-won-t-quit-parliament-before-election
# Inserted data into the database for Jeremy Hunt
# Processing URL 78/116: https://informationcradle.com/jeremy-hunt/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://informationcradle.com/jeremy-hunt/
# Inserted data into the database for Jeremy Hunt
# Processing URL 79/116: https://kat.sfo3.digitaloceanspaces.com/hotnews/who-is-jeremy-hunt-wife-lucia-guo-hunt-wiki-age-nationality-children-instagram-47527.html
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# HTTP Error (403): https://kat.sfo3.digitaloceanspaces.com/hotnews/who-is-jeremy-hunt-wife-lucia-guo-hunt-wiki-age-nationality-children-instagram-47527.html
# False
# The URL is skipped
# Processing URL 80/116: https://www.upi.com/topic/Jeremy_Hunt/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.upi.com/topic/Jeremy_Hunt/
# Inserted data into the database for Jeremy Hunt
# Processing URL 81/116: https://www.nndb.com/people/398/000402189/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.nndb.com/people/398/000402189/
# Inserted data into the database for Jeremy Hunt
# Processing URL 82/116: https://www.famousbirthdays.com/people/jeremy-hunt.html
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.famousbirthdays.com/people/jeremy-hunt.html
# Inserted data into the database for Jeremy Hunt
# Processing URL 83/116: https://www.albanyherald.com/news/columbus-army-veteran-jeremy-hunt-declares-for-u-s-house-district-2/article_c9c6f124-762c-11ec-a209-470bfd8177b1.html
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# HTTP Error (451): https://www.albanyherald.com/news/columbus-army-veteran-jeremy-hunt-declares-for-u-s-house-district-2/article_c9c6f124-762c-11ec-a209-470bfd8177b1.html
# False
# The URL is skipped
# Processing URL 84/116: https://www.lgbtconservatives.org.uk/news/my-business-politics-luke-black-interviews-jeremy-hunt-mp
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.lgbtconservatives.org.uk/news/my-business-politics-luke-black-interviews-jeremy-hunt-mp
# Inserted data into the database for Jeremy Hunt
# Processing URL 85/116: https://books.google.com/books?id=7w99xYuoonwC&pg=PR4&lpg=PR4&dq=Jeremy+Hunt+politician+biography&source=bl&ots=1Mv9SiaWiI&sig=ACfU3U3M_rFXZ3bXZHZRcOjVZLkCQH01zw&hl=en
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://books.google.com/books?id=7w99xYuoonwC&pg=PR4&lpg=PR4&dq=Jeremy+Hunt+politician+biography&source=bl&ots=1Mv9SiaWiI&sig=ACfU3U3M_rFXZ3bXZHZRcOjVZLkCQH01zw&hl=en
# Inserted data into the database for Jeremy Hunt
# Processing URL 86/116: https://www.newstatesman.com/tag/jeremy-hunt
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.newstatesman.com/tag/jeremy-hunt
# Inserted data into the database for Jeremy Hunt
# Processing URL 87/116: https://berlinpolicyjournal.com/close-up-jeremy-hunt-and-dominic-raab/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://berlinpolicyjournal.com/close-up-jeremy-hunt-and-dominic-raab/
# Inserted data into the database for Jeremy Hunt
# Processing URL 88/116: https://www.chartwellspeakers.com/speaker/jeremy-hunt/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.chartwellspeakers.com/speaker/jeremy-hunt/
# Inserted data into the database for Jeremy Hunt
# Processing URL 89/116: https://www.kidpaw.com/famous-people/jeremy-hunt-pid75551
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.kidpaw.com/famous-people/jeremy-hunt-pid75551
# Inserted data into the database for Jeremy Hunt
# Processing URL 90/116: https://time.com/6222642/jeremy-hunt-uk-finance-minister/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://time.com/6222642/jeremy-hunt-uk-finance-minister/
# Inserted data into the database for Jeremy Hunt
# Processing URL 91/116: https://www.techopedia.com/davos-final-thoughts-how-ai-is-reshaping-global-politics
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# HTTP Error (403): https://www.techopedia.com/davos-final-thoughts-how-ai-is-reshaping-global-politics
# False
# The URL is skipped
# Processing URL 92/116: https://apnews.com/article/business-economy-economic-stimulus-jeremy-hunt-9ab5f4e2bd0f278d087516b8127d10e3
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://apnews.com/article/business-economy-economic-stimulus-jeremy-hunt-9ab5f4e2bd0f278d087516b8127d10e3
# Inserted data into the database for Jeremy Hunt
# Processing URL 93/116: https://www.bmj.com/company/newsroom/jeremy-hunt-i-was-too-slow-to-boost-the-nhs-workforce/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.bmj.com/company/newsroom/jeremy-hunt-i-was-too-slow-to-boost-the-nhs-workforce/
# Inserted data into the database for Jeremy Hunt
# Processing URL 94/116: https://www.instituteforgovernment.org.uk/ministers-reflect/jeremy-hunt
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.instituteforgovernment.org.uk/ministers-reflect/jeremy-hunt
# Inserted data into the database for Jeremy Hunt
# Processing URL 95/116: https://www.vice.com/en/article/nevnwq/a-bewilderingly-long-timeline-of-jeremy-hunt-screwing-up
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.vice.com/en/article/nevnwq/a-bewilderingly-long-timeline-of-jeremy-hunt-screwing-up
# Inserted data into the database for Jeremy Hunt
# Processing URL 96/116: https://news.cgtn.com/news/2019-07-08/Jeremy-Hunt-The-underdog-clawing-back-into-UK-PM-race-I9X8UJSTTO/index.html
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://news.cgtn.com/news/2019-07-08/Jeremy-Hunt-The-underdog-clawing-back-into-UK-PM-race-I9X8UJSTTO/index.html
# Inserted data into the database for Jeremy Hunt
# Processing URL 97/116: https://policymogul.com/stakeholders/9505/jeremy-hunt
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://policymogul.com/stakeholders/9505/jeremy-hunt
# Inserted data into the database for Jeremy Hunt
# Processing URL 98/116: https://www.gov.uk/government/people/jeremy-hunt
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.gov.uk/government/people/jeremy-hunt
# Inserted data into the database for Jeremy Hunt
# Processing URL 99/116: https://www.ft.com/content/12222ba4-a82e-451f-8292-ca3015758049
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.ft.com/content/12222ba4-a82e-451f-8292-ca3015758049
# Inserted data into the database for Jeremy Hunt
# Processing URL 100/116: https://www.nytimes.com/by/nicholas-confessore
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.nytimes.com/by/nicholas-confessore
# Inserted data into the database for Jeremy Hunt
# Processing URL 101/116: https://www.thetimes.co.uk/topic/jeremy-hunt?page=2
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.thetimes.co.uk/topic/jeremy-hunt?page=2
# Inserted data into the database for Jeremy Hunt
# Processing URL 102/116: https://www.gov.uk/government/ministers/secretary-of-state-for-health-and-social-care
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.gov.uk/government/ministers/secretary-of-state-for-health-and-social-care
# Inserted data into the database for Jeremy Hunt
# Processing URL 103/116: https://www.independent.co.uk/news/uk/politics/jeremy-hunt-budget-chancellor-health-secretary-b2300566.html
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.independent.co.uk/news/uk/politics/jeremy-hunt-budget-chancellor-health-secretary-b2300566.html
# Inserted data into the database for Jeremy Hunt
# Processing URL 104/116: https://www.cnbc.com/2019/06/21/boris-johnson-and-jeremy-hunt-in-battle-to-be-britains-next-pm.html
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# Skipping PDF: https://www.cnbc.com/2019/06/21/boris-johnson-and-jeremy-hunt-in-battle-to-be-britains-next-pm.html
# False
# The URL is skipped
# Processing URL 105/116: https://www.reuters.com/world/uk/jeremy-hunt-takes-his-biggest-role-yet-uk-finance-minister-2022-10-17/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# HTTP Error (401): https://www.reuters.com/world/uk/jeremy-hunt-takes-his-biggest-role-yet-uk-finance-minister-2022-10-17/
# False
# The URL is skipped
# Processing URL 106/116: https://www.thetimes.co.uk/article/who-is-jeremy-hunt-chancellor-new-bio-profile-pbgrkxkdr
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.thetimes.co.uk/article/who-is-jeremy-hunt-chancellor-new-bio-profile-pbgrkxkdr
# Inserted data into the database for Jeremy Hunt
# Processing URL 107/116: https://www.britannica.com/biography/Sajid-Javid
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.britannica.com/biography/Sajid-Javid
# Inserted data into the database for Jeremy Hunt
# Processing URL 108/116: https://news.sky.com/story/the-by-election-battles-of-rishi-sunaks-premiership-13046025
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://news.sky.com/story/the-by-election-battles-of-rishi-sunaks-premiership-13046025
# Inserted data into the database for Jeremy Hunt
# Processing URL 109/116: https://en-academic.com/dic.nsf/enwiki/9223748https:/en-academic.com/dic.nsf/enwiki/904748
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://en-academic.com/dic.nsf/enwiki/9223748https:/en-academic.com/dic.nsf/enwiki/904748
# Inserted data into the database for Jeremy Hunt
# Processing URL 110/116: https://books.google.com/books?id=Uf5RAAAAcAAJ&pg=PT5&lpg=PT5&dq=Jeremy+Hunt+politician+biography&source=bl&ots=I7Zco--rdH&sig=ACfU3U1Vm0luELfl5MLkm6Q1gMhFrFhzzQ&hl=en
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://books.google.com/books?id=Uf5RAAAAcAAJ&pg=PT5&lpg=PT5&dq=Jeremy+Hunt+politician+biography&source=bl&ots=I7Zco--rdH&sig=ACfU3U1Vm0luELfl5MLkm6Q1gMhFrFhzzQ&hl=en
# Inserted data into the database for Jeremy Hunt
# Processing URL 111/116: https://jeremyhuntdrill.com/about
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://jeremyhuntdrill.com/about
# Inserted data into the database for Jeremy Hunt
# Processing URL 112/116: https://www.lbc.co.uk/news/explained/jeremy-hunt-facts-background-business-politics/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.lbc.co.uk/news/explained/jeremy-hunt-facts-background-business-politics/
# Inserted data into the database for Jeremy Hunt
# Processing URL 113/116: https://metro.co.uk/2023/11/22/jeremy-hunts-family-life-tv-star-wife-properties-19859467/
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://metro.co.uk/2023/11/22/jeremy-hunts-family-life-tv-star-wife-properties-19859467/
# Inserted data into the database for Jeremy Hunt
# Processing URL 114/116: https://olympics.com/en/athletes/jeremy-hunt
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://olympics.com/en/athletes/jeremy-hunt
# Inserted data into the database for Jeremy Hunt
# Processing URL 115/116: https://www.thefamouspeople.com/profiles/jeremy-hunt-50214.php
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://www.thefamouspeople.com/profiles/jeremy-hunt-50214.php
# Inserted data into the database for Jeremy Hunt
# Processing URL 116/116: https://althistory.fandom.com/wiki/Jeremy_Hunt_(For_Want_of_a_Telegram)
# Confirming name: Jeremy Hunt
# Confirming name: Jeremy Hunt
# point 0
# point 1
# point 2
# True
# Scrape success for: https://althistory.fandom.com/wiki/Jeremy_Hunt_(For_Want_of_a_Telegram)
# Inserted data into the database for Jeremy Hunt
# Scraping process completed

# %%
# Configure Database Details
db_host = "127.0.0.1"
db_user = "root"
db_password = ""
db_name = "Mapolitical"

# Connect to MySQL database
try:
    connection = mysql.connector.connect(
        host=db_host,
        user=db_user,
        password=db_password,
        database=db_name
    )
except mysql.connector.Error as err:
    print(f"Error: {err}")
    exit()

cursor = connection.cursor()

# Create CleanedData table if not exists
cursor.execute("""
    CREATE TABLE IF NOT EXISTS CleanedData (
        id INT AUTO_INCREMENT PRIMARY KEY,
        person_id INT,
        url TEXT NOT NULL,
        title TEXT,
        cleaned_text TEXT,
        UNIQUE KEY unique_url (url),
        sentiment_score FLOAT,
        FOREIGN KEY (person_id) REFERENCES Person (id)
    )
""")
connection.commit()

model = Summarizer()

def clean_sentence(sentence):
    global model  # Access the global model variable
    
    summary = model(sentence)
    
    if sentence.strip().lower() == summary.strip().lower():
        return None
    else:
        return sentence
    
def remove_incoherent_sentences(paragraph, threshold=0.2):
    # Load the spaCy English model
    nlp = spacy.load("en_core_web_sm")

    # Tokenize the paragraph into sentences
    doc = nlp(paragraph)
    sentences = [sent.text for sent in doc.sents]

    # Use TF-IDF vectorization to represent sentences as vectors
    vectorizer = TfidfVectorizer()
    sentence_vectors = vectorizer.fit_transform(sentences)

    # Calculate pairwise cosine similarity between sentences
    similarity_matrix = cosine_similarity(sentence_vectors, sentence_vectors)

    # Identify sentences with low similarity to others
    incoherent_sentences = set()
    for i in range(len(sentences)):
        if max(similarity_matrix[i, :]) < threshold:
            incoherent_sentences.add(i)

    # Remove incoherent sentences from the original paragraph
    cleaned_paragraph = ' '.join(sentences[i] for i in range(len(sentences)) if i not in incoherent_sentences)

    return cleaned_paragraph



def clean_and_preprocess_text(title, text, query_string, url):
    try:
        print("Original Text Length:", len(text))

        # Remove HTML tags
        soup = BeautifulSoup(text, "html.parser")
        cleaned_text = soup.get_text()
        
        print("Text after removing HTML tags Length:", len(cleaned_text))
        
        if len(cleaned_text) < 700:
            print("Skipping text with length less than 700:", url)
            return False, None
        
        if len(title) < 10:
            print("Skipping title with length less than 10:", url)
            return False, None

        # Convert to lowercase
        cleaned_text = cleaned_text.lower()
        cleaned_title = title.lower()

        cleaned_text = ' '.join(cleaned_text.split())
        cleaned_title = ' '.join(cleaned_title.split())

        # Remove special characters
        cleaned_text = re.sub(r'[^a-zA-Z0-9.,\s]', '', cleaned_text)
        cleaned_title = re.sub(r'[^a-zA-Z0-9.,\s]', '', cleaned_title)

        print("Text after lowercasing and removing special characters Length:", len(text))
        print("Title after lowercasing and removing special characters Length:", len(cleaned_title))

        # Analyze sentiment to identify promotional or advertisement-like content
        sentiment_analyzer = SentimentIntensityAnalyzer()
        sentiment_score = sentiment_analyzer.polarity_scores(cleaned_text)['compound']
        print("sentiment_score:", sentiment_score)

        # Threshold for considering text as promotional
        promotional_threshold = -0.9998

        if sentiment_score < promotional_threshold:
            print("Skipping promotional or advertisement-like content", url)
            return False, None

        # Split the query_string into individual keywords
        query_keywords = [keyword.strip() for keyword in query_string.split(',')]

        # Initialize a list to store individual scores
        keyword_scores = []

        # Calculate individual scores and store them
        for keyword in query_keywords:
            keyword_scores.append(fuzz.partial_ratio(keyword.lower(), cleaned_text))

        # Calculate the overall score by averaging individual scores
        overall_score = sum(keyword_scores) / len(keyword_scores)
        print("overall_score", overall_score)

        # Set a threshold based on your requirements
        overall_score_threshold = 20

        if overall_score < overall_score_threshold:
            print("Skipping content, as it is not accurately representing the query", url)
            return False, None
        else:
            # Split the text into sentences and clean each sentence using a full stop as the delimiter
            sentences = cleaned_text.split('\n')
            with ThreadPoolExecutor() as executor:
                cleaned_sentences = list(executor.map(clean_sentence, sentences))

            # Remove None values (filtered sentences) and join the cleaned sentences
            cleaned_sentences = '\n'.join(filter(None, cleaned_sentences))
            
            Final_Cleaned_text = remove_incoherent_sentences(cleaned_sentences)
            
            # Find and normalize dates
            matches = datefinder.find_dates(Final_Cleaned_text)

            # Check if there are any matches before entering the loop
            if matches:
                for match in matches:
                    old_date = match.strftime("%Y-%m-%d")  # Change the format as needed
                    new_date = datetime.now().strftime("%Y-%m-%d")  # Change the format as needed

                    Final_Cleaned_text = Final_Cleaned_text.replace(old_date, new_date)


        return True, {"body_text": Final_Cleaned_text, "sentiment_score": sentiment_score, "title": cleaned_title}
    except Exception as e:
        print(f"Error: {e}")
        return False, None

# Fetch records in batches
cursor.execute("""
    SELECT 
        rd.id AS raw_data_id,
        rd.person_id,
        rd.url,
        rd.title,
        rd.body_text,
        p.matching_pattern
    FROM rawdata rd
    JOIN person p ON rd.person_id = p.id
""")
raw_data_records = cursor.fetchall()

total_documents = len(raw_data_records)
batch_size = 100  # Adjust the batch size based on your system's capacity

for batch_start in range(0, total_documents, batch_size):
    batch_end = min(batch_start + batch_size, total_documents)
    batch = raw_data_records[batch_start:batch_end]

    with ThreadPoolExecutor() as executor:
        # Correct the argument unpacking in the lambda function
        cleaned_results = list(executor.map(lambda record: clean_and_preprocess_text(record[3], record[4], record[5], record[2]), batch))

    for key, (raw_data, (success, result)) in enumerate(zip(batch, cleaned_results)):
        document_number = batch_start + key + 1
        print(f"\nCleaning Document {document_number}/{total_documents}")
        print(f"Batch {batch_start // batch_size + 1}/{(total_documents + batch_size - 1) // batch_size}")

        raw_data_id, person_id, url, title, body_text, matching_pattern = raw_data

        # Additional progress details before calling clean_and_preprocess_text
        print(f"Processing document with URL: {url}")
        print(f"Title Length: {len(title)}")
        print(f"Body Text Length: {len(body_text)}")

        # Check if the data already exists in CleanedData
        cursor.execute("SELECT id FROM CleanedData WHERE url = %s", (url,))
        existing_data = cursor.fetchone()

        if success:
            if existing_data:
                # If the data exists, update the existing data
                cursor.execute(
                    "UPDATE CleanedData SET title = %s, cleaned_text = %s, sentiment_score = %s WHERE id = %s",
                    (title, result["body_text"], result["sentiment_score"], existing_data[0]))
                print(f"Updated data in the CleanedData table for URL: {url}")
            else:
                # If the data doesn't exist, insert the cleaned data into the CleanedData table
                cursor.execute(
                    "INSERT INTO CleanedData (person_id, url, title, cleaned_text, sentiment_score) VALUES (%s, %s, %s, %s, %s)",
                    (person_id, url, title, result["body_text"], result["sentiment_score"]))
                print(f"Inserted data into the CleanedData table for URL: {url}")
        else:
            print("Skipping empty result for URL:", url)

# Commit changes and close the connection
connection.commit()
connection.close()
print("\nData cleaning and insertion process completed")
# Out:
# Original Text Length:Original Text Length: 2113
#  9274
# Text after removing HTML tags Length: 9274
# Text after lowercasing and removing special characters Length: 9274
# Title after lowercasing and removing special characters Length: 93
# Original Text Length: 2462
# Text after removing HTML tags Length: 2462
# Text after lowercasing and removing special characters Length: 2462
# Title after lowercasing and removing special characters Length: 59
# Text after removing HTML tags Length: 2113
# Text after lowercasing and removing special characters Length: 2113
# Title after lowercasing and removing special characters Length: 25
# Original Text Length: 1246
# Text after removing HTML tags Length: 1246
# Text after lowercasing and removing special characters Length: 1246
# Title after lowercasing and removing special characters Length: 65
# Original Text Length: 4650
# Text after removing HTML tags Length: 4650
# Text after lowercasing and removing special characters Length: 4650
# Title after lowercasing and removing special characters Length: 59
# Original Text Length: 3098
# Text after removing HTML tags Length: 3098
# Skipping title with length less than 10: https://xampla.com/daniel-zeichner-mp-visits-lab/
# Original Text Length: 2687
# Text after removing HTML tags Length: 2687
# Text after lowercasing and removing special characters Length: 2687
# Title after lowercasing and removing special characters Length: 111
# Original Text Length: 4601
# Text after removing HTML tags Length: 4601
# Text after lowercasing and removing special characters Length: 4601
# Title after lowercasing and removing special characters Length: 95
# Original Text Length: 6818
# Text after removing HTML tags Length: 6818
# Text after lowercasing and removing special characters Length: 6818
# Title after lowercasing and removing special characters Length: 57
# Original Text Length: 5308
# Text after removing HTML tags Length: 5308
# Text after lowercasing and removing special characters Length: 5308
# Title after lowercasing and removing special characters Length: 95
# Original Text Length: 1667
# Text after removing HTML tags Length: 1667
# Text after lowercasing and removing special characters Length: 1667
# Title after lowercasing and removing special characters Length: 71
# Original Text Length: 1198
# Text after removing HTML tags Length: 1198
# Text after lowercasing and removing special characters Length: 1198
# Title after lowercasing and removing special characters Length: 59
# Original Text Length: 4245
# Text after removing HTML tags Length: 4245
# Text after lowercasing and removing special characters Length: 4245
# Title after lowercasing and removing special characters Length: 58
# Original Text Length: 2040
# Text after removing HTML tags Length: 2040
# Text after lowercasing and removing special characters Length: 2040
# Title after lowercasing and removing special characters Length: 72
# Original Text Length: 3473
# Text after removing HTML tags Length: 3473
# Text after lowercasing and removing special characters Length: 3473
# Title after lowercasing and removing special characters Length: 111
# Original Text Length: 885
# Text after removing HTML tags Length: 885
# Text after lowercasing and removing special characters Length: 885
# Title after lowercasing and removing special characters Length: 105
# Original Text Length: 2745
# Text after removing HTML tags Length: 2745
# Text after lowercasing and removing special characters Length: 2745
# Title after lowercasing and removing special characters Length: 60
# sentiment_score: 0.9995
# sentiment_score: -0.9665
# overall_score 72.0
# overall_score 72.0
# sentiment_score: 0.9906
# overall_score 68.0
# sentiment_score: 0.9943
# overall_score 72.0
# sentiment_score: 0.9946
# sentiment_score: 0.9981
# overall_score 24.0
# sentiment_score: 0.967
# overall_score 68.0
# overall_score 68.0
# sentiment_score: 0.9788
# overall_score 68.0
# sentiment_score: 0.9936
# overall_score 68.0
# sentiment_score: 0.9984
# overall_score 32.0
# sentiment_score: 0.524
# overall_score 20.0
# sentiment_score: 0.9792
# overall_score 72.0
# sentiment_score: 0.9958
# overall_score 72.0
# sentiment_score: 0.8885
# overall_score 68.0
# sentiment_score: 0.9955
# overall_score 72.0
# sentiment_score: 0.9899
# overall_score 72.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 5507
# Text after removing HTML tags Length: 5507
# Text after lowercasing and removing special characters Length: 5507
# Title after lowercasing and removing special characters Length: 86
# sentiment_score: 0.2487
# overall_score 36.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 7835
# Text after removing HTML tags Length: 7835
# Text after lowercasing and removing special characters Length: 7835
# Title after lowercasing and removing special characters Length: 143
# sentiment_score: 0.9962
# overall_score 68.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 3571
# Text after removing HTML tags Length: 3571
# Text after lowercasing and removing special characters Length: 3571
# Title after lowercasing and removing special characters Length: 83
# sentiment_score: 0.9995
# overall_score 80.0
# Original Text Length: 1876
# Text after removing HTML tags Length: 1876
# Text after lowercasing and removing special characters Length: 1876
# Title after lowercasing and removing special characters Length: 15
# sentiment_score: 0.9805
# overall_score 32.0
# Original Text Length: 9771
# Text after removing HTML tags Length: 9771
# Text after lowercasing and removing special characters Length: 9771
# Title after lowercasing and removing special characters Length: 99
# sentiment_score: -0.9908
# overall_score 72.0
# Original Text Length: 3042
# Text after removing HTML tags Length: 3042
# Text after lowercasing and removing special characters Length: 3042
# Title after lowercasing and removing special characters Length: 51
# sentiment_score: 0.9906
# overall_score 72.0
# Original Text Length: 7222
# Text after removing HTML tags Length: 7222
# Text after lowercasing and removing special characters Length: 7222
# Title after lowercasing and removing special characters Length: 66
# sentiment_score: 0.9671
# overall_score 72.0
# Original Text Length: 6008
# Text after removing HTML tags Length: 6008
# Text after lowercasing and removing special characters Length: 6008
# Title after lowercasing and removing special characters Length: 73
# sentiment_score: 0.9986
# overall_score 24.0
# Original Text Length: 2404
# Text after removing HTML tags Length: 2404
# Text after lowercasing and removing special characters Length: 2404
# Title after lowercasing and removing special characters Length: 85
# sentiment_score: 0.9605
# overall_score 68.0
# Original Text Length: 5629
# Text after removing HTML tags Length: 5629
# Text after lowercasing and removing special characters Length: 5629
# Title after lowercasing and removing special characters Length: 50
# sentiment_score: 0.9995
# overall_score 68.0
# Original Text Length: 5108
# Text after removing HTML tags Length: 5108
# Text after lowercasing and removing special characters Length: 5108
# Title after lowercasing and removing special characters Length: 60
# sentiment_score: 0.9928
# overall_score 76.0
# Original Text Length: 8842
# Text after removing HTML tags Length: 8842
# Text after lowercasing and removing special characters Length: 8842
# Title after lowercasing and removing special characters Length: 47
# sentiment_score: 0.9965
# overall_score 80.0
# Original Text Length: 993
# Text after removing HTML tags Length: 993
# Text after lowercasing and removing special characters Length: 993
# Title after lowercasing and removing special characters Length: 70
# sentiment_score: 0.926
# overall_score 80.0
# Original Text Length: 4214
# Text after removing HTML tags Length: 4214
# Text after lowercasing and removing special characters Length: 4214
# Title after lowercasing and removing special characters Length: 68
# sentiment_score: 0.9923
# overall_score 72.0
# Original Text Length: 5448
# Text after removing HTML tags Length: 5448
# Text after lowercasing and removing special characters Length: 5448
# Title after lowercasing and removing special characters Length: 78
# sentiment_score: 0.9965
# overall_score 72.0
# Original Text Length: 1480
# Text after removing HTML tags Length: 1480
# Text after lowercasing and removing special characters Length: 1480
# Title after lowercasing and removing special characters Length: 74
# sentiment_score: -0.8834
# overall_score 32.0
# Original Text Length: 4051
# Text after removing HTML tags Length: 4051
# Text after lowercasing and removing special characters Length: 4051
# Title after lowercasing and removing special characters Length: 52
# sentiment_score: 0.9983
# overall_score 72.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 2518
# Text after removing HTML tags Length: 2518
# Text after lowercasing and removing special characters Length: 2518
# Title after lowercasing and removing special characters Length: 101
# sentiment_score: 0.9976
# overall_score 76.0
# Original Text Length: 1048
# Text after removing HTML tags Length: 1048
# Text after lowercasing and removing special characters Length: 1048
# Title after lowercasing and removing special characters Length: 120
# sentiment_score: 0.8979
# overall_score 72.0
# Original Text Length: 3096
# Text after removing HTML tags Length: 3096
# Text after lowercasing and removing special characters Length: 3096
# Title after lowercasing and removing special characters Length: 46
# sentiment_score: 0.997
# overall_score 76.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 3109
# Text after removing HTML tags Length: 3109
# Text after lowercasing and removing special characters Length: 3109
# Title after lowercasing and removing special characters Length: 86
# sentiment_score: 0.9988
# overall_score 76.0
# Original Text Length: 42055
# Text after removing HTML tags Length: 42055
# Text after lowercasing and removing special characters Length: 42055
# Title after lowercasing and removing special characters Length: 68
# sentiment_score: 0.9999
# overall_score 68.0
# Original Text Length: 860
# Text after removing HTML tags Length: 860
# Text after lowercasing and removing special characters Length: 860
# Title after lowercasing and removing special characters Length: 123
# sentiment_score: 0.9936
# overall_score 72.0
# Original Text Length: 4795
# Text after removing HTML tags Length: 4795
# Text after lowercasing and removing special characters Length: 4795
# Title after lowercasing and removing special characters Length: 131
# sentiment_score: 0.9954
# overall_score 24.0
# Original Text Length: 3708
# Text after removing HTML tags Length: 3708
# Text after lowercasing and removing special characters Length: 3708
# Title after lowercasing and removing special characters Length: 104
# sentiment_score: -0.8658
# overall_score 36.0
# Original Text Length: 1465
# Text after removing HTML tags Length: 1465
# Text after lowercasing and removing special characters Length: 1465
# Title after lowercasing and removing special characters Length: 64
# sentiment_score: -0.9393
# overall_score 24.0
# Original Text Length: 3747
# Text after removing HTML tags Length: 3747
# Text after lowercasing and removing special characters Length: 3747
# Title after lowercasing and removing special characters Length: 82
# sentiment_score: 0.9985
# overall_score 36.0
# Original Text Length: 65535
# Text after removing HTML tags Length: 65535
# Text after lowercasing and removing special characters Length: 65535
# Title after lowercasing and removing special characters Length: 15
# sentiment_score: 1.0
# overall_score 28.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 1115
# Text after removing HTML tags Length: 1115
# Text after lowercasing and removing special characters Length: 1115
# Title after lowercasing and removing special characters Length: 37
# sentiment_score: 0.9941
# overall_score 76.0
# Original Text Length: 3246
# Text after removing HTML tags Length: 3246
# Text after lowercasing and removing special characters Length: 3246
# Title after lowercasing and removing special characters Length: 55
# sentiment_score: 0.985
# overall_score 80.0
# Original Text Length: 4310
# Text after removing HTML tags Length: 4310
# Text after lowercasing and removing special characters Length: 4310
# Title after lowercasing and removing special characters Length: 85
# sentiment_score: -0.9314
# overall_score 68.0
# Original Text Length: 2268
# Text after removing HTML tags Length: 2268
# Text after lowercasing and removing special characters Length: 2268
# Title after lowercasing and removing special characters Length: 82
# sentiment_score: 0.9958
# overall_score 68.0
# Original Text Length: 3484
# Text after removing HTML tags Length: 3484
# Text after lowercasing and removing special characters Length: 3484
# Title after lowercasing and removing special characters Length: 94
# sentiment_score: 0.9832
# overall_score 68.0
# Original Text Length: 1243
# Text after removing HTML tags Length: 1243
# Text after lowercasing and removing special characters Length: 1243
# Title after lowercasing and removing special characters Length: 98
# sentiment_score: 0.9799
# overall_score 76.0
# Original Text Length: 4434
# Text after removing HTML tags Length: 4434
# Text after lowercasing and removing special characters Length: 4434
# Title after lowercasing and removing special characters Length: 95
# sentiment_score: 0.9982
# overall_score 68.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 1183
# Text after removing HTML tags Length: 1183
# Text after lowercasing and removing special characters Length: 1183
# Title after lowercasing and removing special characters Length: 32
# sentiment_score: 0.9887
# overall_score 76.0
# Original Text Length: 16305
# Text after removing HTML tags Length: 16305
# Text after lowercasing and removing special characters Length: 16305
# Title after lowercasing and removing special characters Length: 112
# sentiment_score: 0.998
# overall_score 36.0
# Original Text Length: 1613
# Text after removing HTML tags Length: 1613
# Text after lowercasing and removing special characters Length: 1613
# Title after lowercasing and removing special characters Length: 62
# sentiment_score: 0.9863
# overall_score 72.0
# Original Text Length: 1165
# Text after removing HTML tags Length: 1165
# Text after lowercasing and removing special characters Length: 1165
# Title after lowercasing and removing special characters Length: 106
# sentiment_score: 0.2192
# overall_score 72.0
# Original Text Length: 1332
# Text after removing HTML tags Length: 1332
# Text after lowercasing and removing special characters Length: 1332
# Title after lowercasing and removing special characters Length: 87
# sentiment_score: 0.5267
# overall_score 68.0
# Original Text Length: 4559
# Text after removing HTML tags Length: 4559
# Text after lowercasing and removing special characters Length: 4559
# Title after lowercasing and removing special characters Length: 43
# sentiment_score: 0.9984
# overall_score 72.0
# Original Text Length: 3476
# Text after removing HTML tags Length: 3476
# Text after lowercasing and removing special characters Length: 3476
# Title after lowercasing and removing special characters Length: 90
# sentiment_score: 0.9986
# overall_score 20.0
# Original Text Length: 2850
# Text after removing HTML tags Length: 2850
# Text after lowercasing and removing special characters Length: 2850
# Title after lowercasing and removing special characters Length: 71
# sentiment_score: 0.8593
# overall_score 76.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 9178
# Text after removing HTML tags Length: 9178
# Text after lowercasing and removing special characters Length: 9178
# Title after lowercasing and removing special characters Length: 90
# sentiment_score: 0.9898
# overall_score 67.0
# Original Text Length: 4920
# Text after removing HTML tags Length: 4920
# Text after lowercasing and removing special characters Length: 4920
# Title after lowercasing and removing special characters Length: 40
# sentiment_score: -0.8439
# overall_score 10.0
# Skipping content, as it is not accurately representing the query https://www.economist.com/britain/2023/07/27/no-really-rishi-sunak-is-a-right-winger
# Original Text Length: 3270
# Text after removing HTML tags Length: 3270
# Text after lowercasing and removing special characters Length: 3270
# Title after lowercasing and removing special characters Length: 77
# sentiment_score: 0.9906
# overall_score 14.0
# Skipping content, as it is not accurately representing the query https://www.history.co.uk/articles/little-known-facts-about-rishi-sunak
# Original Text Length: 5192
# Text after removing HTML tags Length: 5192
# Text after lowercasing and removing special characters Length: 5192
# Title after lowercasing and removing special characters Length: 100
# sentiment_score: 0.9989
# overall_score 14.0
# Skipping content, as it is not accurately representing the query https://www.express.co.uk/news/politics/1859242/rishi-sunak-replacement-tory-leader-runners-riders-kemi-badenoch
# Original Text Length: 30884
# Text after removing HTML tags Length: 30884
# Text after lowercasing and removing special characters Length: 30884
# Title after lowercasing and removing special characters Length: 22
# sentiment_score: 0.9996
# overall_score 62.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 5231
# Text after removing HTML tags Length: 5231
# Text after lowercasing and removing special characters Length: 5231
# Title after lowercasing and removing special characters Length: 58
# sentiment_score: 0.9957
# overall_score 24.0
# Original Text Length: 5499
# Text after removing HTML tags Length: 5499
# Text after lowercasing and removing special characters Length: 5499
# Title after lowercasing and removing special characters Length: 84
# sentiment_score: 0.9548
# overall_score 24.0
# Original Text Length: 1390
# Text after removing HTML tags Length: 1390
# Text after lowercasing and removing special characters Length: 1390
# Title after lowercasing and removing special characters Length: 51
# sentiment_score: 0.849
# overall_score 29.0
# Original Text Length: 4031
# Text after removing HTML tags Length: 4031
# Text after lowercasing and removing special characters Length: 4031
# Title after lowercasing and removing special characters Length: 124
# sentiment_score: 0.9982
# overall_score 10.0
# Skipping content, as it is not accurately representing the query https://www.psa.ac.uk/psa/news/it-matters-rishi-sunak-has-become-uk%E2%80%99s-first-prime-minister-indian-descent
# Original Text Length: 1044
# Text after removing HTML tags Length: 1044
# Text after lowercasing and removing special characters Length: 1044
# Title after lowercasing and removing special characters Length: 72
# sentiment_score: 0.8934
# overall_score 29.0
# Original Text Length: 3399
# Text after removing HTML tags Length: 3399
# Text after lowercasing and removing special characters Length: 3399
# Title after lowercasing and removing special characters Length: 108
# sentiment_score: 0.9907
# overall_score 33.0
# Original Text Length: 2553
# Text after removing HTML tags Length: 2553
# Text after lowercasing and removing special characters Length: 2553
# Title after lowercasing and removing special characters Length: 33
# sentiment_score: 0.9937
# overall_score 48.0
# Original Text Length: 1038
# Text after removing HTML tags Length: 1038
# Text after lowercasing and removing special characters Length: 1038
# Title after lowercasing and removing special characters Length: 68
# sentiment_score: 0.7906
# overall_score 19.0
# Skipping content, as it is not accurately representing the query https://www.nytimes.com/2023/11/14/world/europe/uk-sunak-david-cameron.html
# Original Text Length: 5446
# Text after removing HTML tags Length: 5446
# Text after lowercasing and removing special characters Length: 5446
# Title after lowercasing and removing special characters Length: 89
# sentiment_score: 0.9877
# overall_score 67.0
# Original Text Length: 5460
# Text after removing HTML tags Length: 5460
# Text after lowercasing and removing special characters Length: 5460
# Title after lowercasing and removing special characters Length: 55
# sentiment_score: 0.9463
# overall_score 19.0
# Skipping content, as it is not accurately representing the query https://www.democratic-erosion.com/2022/12/22/rishi-sunak-and-the-post-post-racial-politics-of-identity/
# Original Text Length: 2208
# Text after removing HTML tags Length: 2208
# Text after lowercasing and removing special characters Length: 2208
# Title after lowercasing and removing special characters Length: 68
# sentiment_score: 0.9723
# overall_score 67.0
# Error: 'NoneType' object has no attribute 'split'
# Original Text Length: 1715
# Text after removing HTML tags Length: 1715
# Text after lowercasing and removing special characters Length: 1715
# Title after lowercasing and removing special characters Length: 19
# sentiment_score: 0.9578
# overall_score 71.0
# Original Text Length: 3201
# Text after removing HTML tags Length: 3201
# Text after lowercasing and removing special characters Length: 3201
# Title after lowercasing and removing special characters Length: 61
# sentiment_score: 0.9313
# overall_score 67.0
# Original Text Length: 2629
# Text after removing HTML tags Length: 2629
# Text after lowercasing and removing special characters Length: 2629
# Title after lowercasing and removing special characters Length: 21
# sentiment_score: 0.8481
# overall_score 38.0
# Original Text Length: 1757
# Text after removing HTML tags Length: 1757
# Text after lowercasing and removing special characters Length: 1757
# Title after lowercasing and removing special characters Length: 86
# sentiment_score: 0.8625
# overall_score 48.0
# Original Text Length: 2826
# Text after removing HTML tags Length: 2826
# Text after lowercasing and removing special characters Length: 2826
# Title after lowercasing and removing special characters Length: 110
# sentiment_score: -0.9662
# overall_score 29.0
# Original Text Length: 7261
# Text after removing HTML tags Length: 7261
# Text after lowercasing and removing special characters Length: 7261
# Title after lowercasing and removing special characters Length: 63
# sentiment_score: 0.9883
# overall_score 62.0
# Original Text Length: 5143
# Text after removing HTML tags Length: 5143
# Text after lowercasing and removing special characters Length: 5143
# Title after lowercasing and removing special characters Length: 95
# sentiment_score: 0.9116
# overall_score 29.0
# Original Text Length: 7794
# Text after removing HTML tags Length: 7794
# Text after lowercasing and removing special characters Length: 7794
# Title after lowercasing and removing special characters Length: 39
# sentiment_score: 0.9955
# overall_score 62.0
# Original Text Length: 3539
# Text after removing HTML tags Length: 3539
# Text after lowercasing and removing special characters Length: 3539
# Title after lowercasing and removing special characters Length: 80
# sentiment_score: 0.9945
# overall_score 76.0
# Original Text Length: 2606
# Text after removing HTML tags Length: 2606
# Text after lowercasing and removing special characters Length: 2606
# Title after lowercasing and removing special characters Length: 80
# sentiment_score: 0.981
# overall_score 67.0
# Original Text Length: 5441
# Text after removing HTML tags Length: 5441
# Text after lowercasing and removing special characters Length: 5441
# Title after lowercasing and removing special characters Length: 84
# sentiment_score: 0.9903
# overall_score 71.0
# Original Text Length: 8654
# Text after removing HTML tags Length: 8654
# Text after lowercasing and removing special characters Length: 8654
# Title after lowercasing and removing special characters Length: 62
# sentiment_score: 0.9981
# overall_score 19.0
# Skipping content, as it is not accurately representing the query https://www.britannica.com/biography/Rishi-Sunak
# Original Text Length: 2698
# Text after removing HTML tags Length: 2698
# Text after lowercasing and removing special characters Length: 2698
# Title after lowercasing and removing special characters Length: 11
# sentiment_score: 0.9661
# overall_score 67.0
# Original Text Length: 12446
# Text after removing HTML tags Length: 12446
# Text after lowercasing and removing special characters Length: 12446
# Title after lowercasing and removing special characters Length: 108
# sentiment_score: 0.9994
# overall_score 24.0
# Original Text Length: 5201
# Text after removing HTML tags Length: 5201
# Text after lowercasing and removing special characters Length: 5201
# Title after lowercasing and removing special characters Length: 76
# sentiment_score: 0.994
# overall_score 62.0
# Original Text Length: 1727
# Text after removing HTML tags Length: 1727
# Text after lowercasing and removing special characters Length: 1727
# Title after lowercasing and removing special characters Length: 22
# sentiment_score: 0.9866
# overall_score 48.0
# Original Text Length: 7632
# Text after removing HTML tags Length: 7632
# Text after lowercasing and removing special characters Length: 7632
# Title after lowercasing and removing special characters Length: 53
# sentiment_score: 0.9959
# overall_score 19.0
# Skipping content, as it is not accurately representing the query https://theweek.com/107488/will-rishi-sunak-become-tory-leader-prime-minister
# Original Text Length: 3483
# Text after removing HTML tags Length: 3483
# Text after lowercasing and removing special characters Length: 3483
# Title after lowercasing and removing special characters Length: 71
# sentiment_score: 0.9966
# overall_score 29.0
# Original Text Length: 5795
# Text after removing HTML tags Length: 5795
# Text after lowercasing and removing special characters Length: 5795
# Title after lowercasing and removing special characters Length: 77
# sentiment_score: 0.9892
# overall_score 29.0
# Original Text Length: 12095
# Text after removing HTML tags Length: 12095
# Text after lowercasing and removing special characters Length: 12095
# Title after lowercasing and removing special characters Length: 68
# sentiment_score: 0.9989
# overall_score 67.0
# Original Text Length: 39329
# Text after removing HTML tags Length: 39329
# Text after lowercasing and removing special characters Length: 39329
# Title after lowercasing and removing special characters Length: 102
# sentiment_score: 0.9999
# overall_score 14.0
# Skipping content, as it is not accurately representing the query https://www.nytimes.com/live/2022/10/25/world/uk-prime-minister-rishi-sunak
# Original Text Length: 4561
# Text after removing HTML tags Length: 4561
# Text after lowercasing and removing special characters Length: 4561
# Title after lowercasing and removing special characters Length: 81
# sentiment_score: 0.9973
# overall_score 24.0
# Original Text Length: 3770
# Text after removing HTML tags Length: 3770
# Text after lowercasing and removing special characters Length: 3770
# Title after lowercasing and removing special characters Length: 52
# sentiment_score: 0.979
# overall_score 29.0
# Original Text Length: 5480
# Text after removing HTML tags Length: 5480
# Text after lowercasing and removing special characters Length: 5480
# Title after lowercasing and removing special characters Length: 86
# sentiment_score: 0.9963
# overall_score 38.0
#
# Cleaning Document 1/782
# Batch 1/8
# Processing document with URL: https://www.thejc.com/news/general-election-round-up-jewish-candidates-win-seats-across-the-country-m0kgxtu2
# Title Length: 96
# Body Text Length: 9274
# Inserted data into the CleanedData table for URL: https://www.thejc.com/news/general-election-round-up-jewish-candidates-win-seats-across-the-country-m0kgxtu2
#
# Cleaning Document 2/782
# Batch 1/8
# Processing document with URL: https://www.danielzeichner.co.uk/about/
# Title Length: 30
# Body Text Length: 2113
# Inserted data into the CleanedData table for URL: https://www.danielzeichner.co.uk/about/
#
# Cleaning Document 3/782
# Batch 1/8
# Processing document with URL: https://www.networkrailmediacentre.co.uk/news/cambridge-mp-daniel-zeichner-visits-site-of-new-gbp-50m-station
# Title Length: 60
# Body Text Length: 2462
# Inserted data into the CleanedData table for URL: https://www.networkrailmediacentre.co.uk/news/cambridge-mp-daniel-zeichner-visits-site-of-new-gbp-50m-station
#
# Cleaning Document 4/782
# Batch 1/8
# Processing document with URL: https://www.cambridge-news.co.uk/incoming/bright-young-minds-lesson-democracy-12680847
# Title Length: 68
# Body Text Length: 1246
# Skipping empty result for URL: https://www.cambridge-news.co.uk/incoming/bright-young-minds-lesson-democracy-12680847
#
# Cleaning Document 5/782
# Batch 1/8
# Processing document with URL: https://www.theguardian.com/science/political-science/2016/mar/12/why-the-eu-matters-for-universities
# Title Length: 61
# Body Text Length: 4650
# Inserted data into the CleanedData table for URL: https://www.theguardian.com/science/political-science/2016/mar/12/why-the-eu-matters-for-universities
#
# Cleaning Document 6/782
# Batch 1/8
# Processing document with URL: https://xampla.com/daniel-zeichner-mp-visits-lab/
# Title Length: 8
# Body Text Length: 3098
# Skipping empty result for URL: https://xampla.com/daniel-zeichner-mp-visits-lab/
#
# Cleaning Document 7/782
# Batch 1/8
# Processing document with URL: https://www.cambridgeindependent.co.uk/news/opinion-inaction-isn-t-an-option-but-all-tories-do-is-opp-9279511/
# Title Length: 114
# Body Text Length: 2687
# Inserted data into the CleanedData table for URL: https://www.cambridgeindependent.co.uk/news/opinion-inaction-isn-t-an-option-but-all-tories-do-is-opp-9279511/
#
# Cleaning Document 8/782
# Batch 1/8
# Processing document with URL: https://voxpoliticalonline.com/2024/01/22/more-than-40-tory-mps-demand-extra-funding-for-the-councils-theyve-been-starving/
# Title Length: 97
# Body Text Length: 4601
# Inserted data into the CleanedData table for URL: https://voxpoliticalonline.com/2024/01/22/more-than-40-tory-mps-demand-extra-funding-for-the-councils-theyve-been-starving/
#
# Cleaning Document 9/782
# Batch 1/8
# Processing document with URL: https://www.varsity.co.uk/interviews/18333
# Title Length: 59
# Body Text Length: 6818
# Inserted data into the CleanedData table for URL: https://www.varsity.co.uk/interviews/18333
#
# Cleaning Document 10/782
# Batch 1/8
# Processing document with URL: https://www.theguardian.com/science/political-science/2017/dec/15/data-will-change-the-world-and-we-must-get-its-governance-right
# Title Length: 97
# Body Text Length: 5308
# Inserted data into the CleanedData table for URL: https://www.theguardian.com/science/political-science/2017/dec/15/data-will-change-the-world-and-we-must-get-its-governance-right
#
# Cleaning Document 11/782
# Batch 1/8
# Processing document with URL: https://www.huntspost.co.uk/news/23915043.cambridge-daniel-zeichner-says-foodbank-use-shameful/
# Title Length: 75
# Body Text Length: 1667
# Inserted data into the CleanedData table for URL: https://www.huntspost.co.uk/news/23915043.cambridge-daniel-zeichner-says-foodbank-use-shameful/
#
# Cleaning Document 12/782
# Batch 1/8
# Processing document with URL: http://www.eng.cam.ac.uk/news/cambridge-climate-lecture-series-0
# Title Length: 60
# Body Text Length: 1198
# Skipping empty result for URL: http://www.eng.cam.ac.uk/news/cambridge-climate-lecture-series-0
#
# Cleaning Document 13/782
# Batch 1/8
# Processing document with URL: https://www.league.org.uk/news-and-resources/news/league-against-cruel-sports-political-party-conferences/
# Title Length: 58
# Body Text Length: 4245
# Inserted data into the CleanedData table for URL: https://www.league.org.uk/news-and-resources/news/league-against-cruel-sports-political-party-conferences/
#
# Cleaning Document 14/782
# Batch 1/8
# Processing document with URL: https://www.elystandard.co.uk/news/23862673.mp-daniel-zeichner-demands-compensation-cambridgeshire/
# Title Length: 73
# Body Text Length: 2040
# Inserted data into the CleanedData table for URL: https://www.elystandard.co.uk/news/23862673.mp-daniel-zeichner-demands-compensation-cambridgeshire/
#
# Cleaning Document 15/782
# Batch 1/8
# Processing document with URL: https://www.electoral-reform.org.uk/mps-step-up-parliamentary-push-for-electoral-reform-with-new-cross-party-campaign/
# Title Length: 114
# Body Text Length: 3473
# Inserted data into the CleanedData table for URL: https://www.electoral-reform.org.uk/mps-step-up-parliamentary-push-for-electoral-reform-with-new-cross-party-campaign/
#
# Cleaning Document 16/782
# Batch 1/8
# Processing document with URL: https://www.farmersguardian.com/news/4122776/roam-labour-policy-open-access-widen-urban-rural-divide
# Title Length: 111
# Body Text Length: 885
# Skipping empty result for URL: https://www.farmersguardian.com/news/4122776/roam-labour-policy-open-access-widen-urban-rural-divide
#
# Cleaning Document 17/782
# Batch 1/8
# Processing document with URL: https://bikebiz.com/cambridge-mp-appointed-as-labours-cycling-spokesman/
# Title Length: 62
# Body Text Length: 2745
# Inserted data into the CleanedData table for URL: https://bikebiz.com/cambridge-mp-appointed-as-labours-cycling-spokesman/
#
# Cleaning Document 18/782
# Batch 1/8
# Processing document with URL: https://www.telegraph.co.uk/politics/2024/01/18/labour-fast-track-countryside-wind-turbines-solar-net-zero/
# Title Length: 87
# Body Text Length: 5507
# Inserted data into the CleanedData table for URL: https://www.telegraph.co.uk/politics/2024/01/18/labour-fast-track-countryside-wind-turbines-solar-net-zero/
#
# Cleaning Document 19/782
# Batch 1/8
# Processing document with URL: https://cambridgetownowl.com/2021/12/05/cambridge-mp-daniel-zeichner-county-council-leader-cllr-lucy-nethsingha-criticise-tory-devolution-model-live-on-telly/
# Title Length: 145
# Body Text Length: 7835
# Inserted data into the CleanedData table for URL: https://cambridgetownowl.com/2021/12/05/cambridge-mp-daniel-zeichner-county-council-leader-cllr-lucy-nethsingha-criticise-tory-devolution-model-live-on-telly/
#
# Cleaning Document 20/782
# Batch 1/8
# Processing document with URL: https://www.cambridgeshirechamber.co.uk/cambridge/lsip-attend-the-innovate-cambridge-summit-2023/
# Title Length: 84
# Body Text Length: 3571
# Inserted data into the CleanedData table for URL: https://www.cambridgeshirechamber.co.uk/cambridge/lsip-attend-the-innovate-cambridge-summit-2023/
#
# Cleaning Document 21/782
# Batch 1/8
# Processing document with URL: https://www.economist.com/britain/2015/02/23/greening-spires
# Title Length: 15
# Body Text Length: 1876
# Inserted data into the CleanedData table for URL: https://www.economist.com/britain/2015/02/23/greening-spires
#
# Cleaning Document 22/782
# Batch 1/8
# Processing document with URL: http://www.rtaylor.co.uk/zeichner-id-card-position.html
# Title Length: 100
# Body Text Length: 9771
# Inserted data into the CleanedData table for URL: http://www.rtaylor.co.uk/zeichner-id-card-position.html
#
# Cleaning Document 23/782
# Batch 1/8
# Processing document with URL: https://www.aru.ac.uk/news/cambridge-mp-learns-about-key-educational-tool
# Title Length: 52
# Body Text Length: 3042
# Inserted data into the CleanedData table for URL: https://www.aru.ac.uk/news/cambridge-mp-learns-about-key-educational-tool
#
# Cleaning Document 24/782
# Batch 1/8
# Processing document with URL: https://www.cambridgesu.co.uk/news/article/cambridgesu/Solidarity-with-the-Trans-Community-Update-from-Daniel-Zeichner-MP/
# Title Length: 72
# Body Text Length: 7222
# Inserted data into the CleanedData table for URL: https://www.cambridgesu.co.uk/news/article/cambridgesu/Solidarity-with-the-Trans-Community-Update-from-Daniel-Zeichner-MP/
#
# Cleaning Document 25/782
# Batch 1/8
# Processing document with URL: https://www.fwi.co.uk/news/farm-policy/analysis-how-is-the-political-outlook-for-2024-shaping-up
# Title Length: 76
# Body Text Length: 6008
# Inserted data into the CleanedData table for URL: https://www.fwi.co.uk/news/farm-policy/analysis-how-is-the-political-outlook-for-2024-shaping-up
#
# Cleaning Document 26/782
# Batch 1/8
# Processing document with URL: https://www.iwf.org.uk/news-media/news/cambridge-mp-daniel-zeichner-to-learn-about-the-work-of-the-internet-watch-foundation/
# Title Length: 85
# Body Text Length: 2404
# Inserted data into the CleanedData table for URL: https://www.iwf.org.uk/news-media/news/cambridge-mp-daniel-zeichner-to-learn-about-the-work-of-the-internet-watch-foundation/
#
# Cleaning Document 27/782
# Batch 1/8
# Processing document with URL: https://www.fruitnet.com/fresh-produce-journal/organic-ag-must-be-mainstreamed/256881.article
# Title Length: 54
# Body Text Length: 5629
# Inserted data into the CleanedData table for URL: https://www.fruitnet.com/fresh-produce-journal/organic-ag-must-be-mainstreamed/256881.article
#
# Cleaning Document 28/782
# Batch 1/8
# Processing document with URL: https://allfamousbirthday.com/daniel-zeichner/
# Title Length: 62
# Body Text Length: 5108
# Inserted data into the CleanedData table for URL: https://allfamousbirthday.com/daniel-zeichner/
#
# Cleaning Document 29/782
# Batch 1/8
# Processing document with URL: https://en.wikipedia.org/wiki/Cambridge_(UK_Parliament_constituency)
# Title Length: 50
# Body Text Length: 8842
# Inserted data into the CleanedData table for URL: https://en.wikipedia.org/wiki/Cambridge_(UK_Parliament_constituency)
#
# Cleaning Document 30/782
# Batch 1/8
# Processing document with URL: https://whocanivotefor.co.uk/person/45/daniel-zeichner
# Title Length: 123
# Body Text Length: 993
# Skipping empty result for URL: https://whocanivotefor.co.uk/person/45/daniel-zeichner
#
# Cleaning Document 31/782
# Batch 1/8
# Processing document with URL: https://www.newstatesman.com/politics/2017/09/cambridge-mp-daniel-zeichner-brexit-people-might-want-rethink
# Title Length: 74
# Body Text Length: 4214
# Inserted data into the CleanedData table for URL: https://www.newstatesman.com/politics/2017/09/cambridge-mp-daniel-zeichner-brexit-people-might-want-rethink
#
# Cleaning Document 32/782
# Batch 1/8
# Processing document with URL: https://uk.news.yahoo.com/suffolk-farmers-feeling-reassured-future-092756118.html/1000
# Title Length: 80
# Body Text Length: 5448
# Inserted data into the CleanedData table for URL: https://uk.news.yahoo.com/suffolk-farmers-feeling-reassured-future-092756118.html/1000
#
# Cleaning Document 33/782
# Batch 1/8
# Processing document with URL: https://www.bbc.com/news/uk-england-cambridgeshire-68023157
# Title Length: 78
# Body Text Length: 1480
# Inserted data into the CleanedData table for URL: https://www.bbc.com/news/uk-england-cambridgeshire-68023157
#
# Cleaning Document 34/782
# Batch 1/8
# Processing document with URL: https://www.aru.ac.uk/news/daniel-zeichner-visits-new-youth-project-at-aru
# Title Length: 53
# Body Text Length: 4051
# Inserted data into the CleanedData table for URL: https://www.aru.ac.uk/news/daniel-zeichner-visits-new-youth-project-at-aru
#
# Cleaning Document 35/782
# Batch 1/8
# Processing document with URL: https://www.cambridgenetwork.co.uk/news/daniel-zeichner-mp-gets-latest-evidence-intelligent-farming-and-food-supply
# Title Length: 102
# Body Text Length: 2518
# Inserted data into the CleanedData table for URL: https://www.cambridgenetwork.co.uk/news/daniel-zeichner-mp-gets-latest-evidence-intelligent-farming-and-food-supply
#
# Cleaning Document 36/782
# Batch 1/8
# Processing document with URL: https://www.farmersguardian.com/news/4123818/farmers-guardian-podcast-labours-daniel-zeichner-answers-farmers-questions-roam
# Title Length: 125
# Body Text Length: 1048
# Skipping empty result for URL: https://www.farmersguardian.com/news/4123818/farmers-guardian-podcast-labours-daniel-zeichner-answers-farmers-questions-roam
#
# Cleaning Document 37/782
# Batch 1/8
# Processing document with URL: https://www.longroad.ac.uk/page/?title=Politics+A+Level&pid=95
# Title Length: 47
# Body Text Length: 3096
# Inserted data into the CleanedData table for URL: https://www.longroad.ac.uk/page/?title=Politics+A+Level&pid=95
#
# Cleaning Document 38/782
# Batch 1/8
# Processing document with URL: https://www.fenews.co.uk/education/mp-daniel-zeichner-shares-expertise-with-cambridge-regional-college-students/
# Title Length: 88
# Body Text Length: 3109
# Inserted data into the CleanedData table for URL: https://www.fenews.co.uk/education/mp-daniel-zeichner-shares-expertise-with-cambridge-regional-college-students/
#
# Cleaning Document 39/782
# Batch 1/8
# Processing document with URL: https://voteclimate.uk/mps/daniel-zeichner/parliament/speeches
# Title Length: 71
# Body Text Length: 42055
# Inserted data into the CleanedData table for URL: https://voteclimate.uk/mps/daniel-zeichner/parliament/speeches
#
# Cleaning Document 40/782
# Batch 1/8
# Processing document with URL: https://www.kingswaygolfcentre.co.uk/local-cambridge-mp-daniel-visits-kingsway-cambridge-lakes/
# Title Length: 126
# Body Text Length: 860
# Skipping empty result for URL: https://www.kingswaygolfcentre.co.uk/local-cambridge-mp-daniel-visits-kingsway-cambridge-lakes/
#
# Cleaning Document 41/782
# Batch 1/8
# Processing document with URL: https://www.pig-world.co.uk/news/spencer-confirms-plan-to-introduce-pig-contractual-regulations-in-the-summer-as-fairness-in-the-supply-chain-is-debated.html
# Title Length: 132
# Body Text Length: 4795
# Inserted data into the CleanedData table for URL: https://www.pig-world.co.uk/news/spencer-confirms-plan-to-introduce-pig-contractual-regulations-in-the-summer-as-fairness-in-the-supply-chain-is-debated.html
#
# Cleaning Document 42/782
# Batch 1/8
# Processing document with URL: https://news.sky.com/story/more-than-40-tory-mps-urge-rishi-sunak-to-boost-funding-for-struggling-councils-13053815
# Title Length: 106
# Body Text Length: 3708
# Inserted data into the CleanedData table for URL: https://news.sky.com/story/more-than-40-tory-mps-urge-rishi-sunak-to-boost-funding-for-struggling-councils-13053815
#
# Cleaning Document 43/782
# Batch 1/8
# Processing document with URL: https://news.yahoo.com/post-office-scandal-cambridge-mp-080622372.html
# Title Length: 67
# Body Text Length: 1465
# Inserted data into the CleanedData table for URL: https://news.yahoo.com/post-office-scandal-cambridge-mp-080622372.html
#
# Cleaning Document 44/782
# Batch 1/8
# Processing document with URL: https://www.peteraldous.com/news/levelling-east-england
# Title Length: 85
# Body Text Length: 3747
# Inserted data into the CleanedData table for URL: https://www.peteraldous.com/news/levelling-east-england
#
# Cleaning Document 45/782
# Batch 1/8
# Processing document with URL: https://www.parallelparliament.co.uk/mp/daniel-zeichner
# Title Length: 18
# Body Text Length: 65535
# Inserted data into the CleanedData table for URL: https://www.parallelparliament.co.uk/mp/daniel-zeichner
#
# Cleaning Document 46/782
# Batch 1/8
# Processing document with URL: https://www.cambridgenetwork.co.uk/directories/companies/3455
# Title Length: 38
# Body Text Length: 1115
# Inserted data into the CleanedData table for URL: https://www.cambridgenetwork.co.uk/directories/companies/3455
#
# Cleaning Document 47/782
# Batch 1/8
# Processing document with URL: https://ukandeu.ac.uk/another-unpredictable-election/
# Title Length: 57
# Body Text Length: 3246
# Inserted data into the CleanedData table for URL: https://ukandeu.ac.uk/another-unpredictable-election/
#
# Cleaning Document 48/782
# Batch 1/8
# Processing document with URL: https://www.cambridgeindependent.co.uk/news/heidi-allen-and-daniel-zeichner-illustrate-the-grey-areas-of-black-and-white-politics-9053686/
# Title Length: 85
# Body Text Length: 4310
# Inserted data into the CleanedData table for URL: https://www.cambridgeindependent.co.uk/news/heidi-allen-and-daniel-zeichner-illustrate-the-grey-areas-of-black-and-white-politics-9053686/
#
# Cleaning Document 49/782
# Batch 1/8
# Processing document with URL: https://www.poultrynews.co.uk/business-politics/food-security-is-top-priority-says-shadow-food-and-farming-minister.html
# Title Length: 85
# Body Text Length: 2268
# Inserted data into the CleanedData table for URL: https://www.poultrynews.co.uk/business-politics/food-security-is-top-priority-says-shadow-food-and-farming-minister.html
#
# Cleaning Document 50/782
# Batch 1/8
# Processing document with URL: https://www.varsity.co.uk/interviews/24279
# Title Length: 99
# Body Text Length: 3484
# Inserted data into the CleanedData table for URL: https://www.varsity.co.uk/interviews/24279
#
# Cleaning Document 51/782
# Batch 1/8
# Processing document with URL: http://www.exeduk.com/question-on-impact-of-brexit-on-eu-student-numbers-from-daniel-zeichner-mp
# Title Length: 99
# Body Text Length: 1243
# Skipping empty result for URL: http://www.exeduk.com/question-on-impact-of-brexit-on-eu-student-numbers-from-daniel-zeichner-mp
#
# Cleaning Document 52/782
# Batch 1/8
# Processing document with URL: https://www.poultrynews.co.uk/business-politics/analysis-food-security-is-the-message-to-hammer-home-as-a-general-election-looms.html
# Title Length: 97
# Body Text Length: 4434
# Inserted data into the CleanedData table for URL: https://www.poultrynews.co.uk/business-politics/analysis-food-security-is-the-message-to-hammer-home-as-a-general-election-looms.html
#
# Cleaning Document 53/782
# Batch 1/8
# Processing document with URL: https://www.stmaryscambridge.co.uk/news-and-blog/view~daniel-zeichner-mp-visits-year-6_7711.htm
# Title Length: 37
# Body Text Length: 1183
# Inserted data into the CleanedData table for URL: https://www.stmaryscambridge.co.uk/news-and-blog/view~daniel-zeichner-mp-visits-year-6_7711.htm
#
# Cleaning Document 54/782
# Batch 1/8
# Processing document with URL: https://www.telegraph.co.uk/politics/2024/01/19/rishi-sunak-latest-news-tories-rwanda-bill-george-osborne/
# Title Length: 113
# Body Text Length: 16305
# Inserted data into the CleanedData table for URL: https://www.telegraph.co.uk/politics/2024/01/19/rishi-sunak-latest-news-tories-rwanda-bill-george-osborne/
#
# Cleaning Document 55/782
# Batch 1/8
# Processing document with URL: https://www.politicshome.com/thehouse/mp-directory/daniel-zeichner.htm
# Title Length: 67
# Body Text Length: 1613
# Skipping empty result for URL: https://www.politicshome.com/thehouse/mp-directory/daniel-zeichner.htm
#
# Cleaning Document 56/782
# Batch 1/8
# Processing document with URL: https://www.huffingtonpost.co.uk/entry/pmqs-daniel-zeichner-says-brexit-labour-shortage-has-dealt-blow-to-great-british-pub_uk_59b91e38e4b086432b02e7a6
# Title Length: 110
# Body Text Length: 1165
# Skipping empty result for URL: https://www.huffingtonpost.co.uk/entry/pmqs-daniel-zeichner-says-brexit-labour-shortage-has-dealt-blow-to-great-british-pub_uk_59b91e38e4b086432b02e7a6
#
# Cleaning Document 57/782
# Batch 1/8
# Processing document with URL: https://www.cser.ac.uk/news/cambridge-students-join-forces-mps-launch-appg-com/
# Title Length: 88
# Body Text Length: 1332
# Inserted data into the CleanedData table for URL: https://www.cser.ac.uk/news/cambridge-students-join-forces-mps-launch-appg-com/
#
# Cleaning Document 58/782
# Batch 1/8
# Processing document with URL: https://www.politicshome.com/thehouse/article/big-data-is-a-big-deal-and-its-here-to-stay
# Title Length: 49
# Body Text Length: 4559
# Inserted data into the CleanedData table for URL: https://www.politicshome.com/thehouse/article/big-data-is-a-big-deal-and-its-here-to-stay
#
# Cleaning Document 59/782
# Batch 1/8
# Processing document with URL: http://www.bonisonesproductions.com/lookingglass/index.html
# Title Length: 92
# Body Text Length: 3476
# Inserted data into the CleanedData table for URL: http://www.bonisonesproductions.com/lookingglass/index.html
#
# Cleaning Document 60/782
# Batch 1/8
# Processing document with URL: https://peoplepill.com/i/daniel-zeichner/
# Title Length: 77
# Body Text Length: 2850
# Inserted data into the CleanedData table for URL: https://peoplepill.com/i/daniel-zeichner/
#
# Cleaning Document 61/782
# Batch 1/8
# Processing document with URL: https://ca.news.yahoo.com/london-politics-latest-rishi-sunak-120405329.html
# Title Length: 93
# Body Text Length: 9178
# Inserted data into the CleanedData table for URL: https://ca.news.yahoo.com/london-politics-latest-rishi-sunak-120405329.html
#
# Cleaning Document 62/782
# Batch 1/8
# Processing document with URL: https://www.economist.com/britain/2023/07/27/no-really-rishi-sunak-is-a-right-winger
# Title Length: 41
# Body Text Length: 4920
# Skipping empty result for URL: https://www.economist.com/britain/2023/07/27/no-really-rishi-sunak-is-a-right-winger
#
# Cleaning Document 63/782
# Batch 1/8
# Processing document with URL: https://www.history.co.uk/articles/little-known-facts-about-rishi-sunak
# Title Length: 79
# Body Text Length: 3270
# Skipping empty result for URL: https://www.history.co.uk/articles/little-known-facts-about-rishi-sunak
#
# Cleaning Document 64/782
# Batch 1/8
# Processing document with URL: https://www.express.co.uk/news/politics/1859242/rishi-sunak-replacement-tory-leader-runners-riders-kemi-badenoch
# Title Length: 104
# Body Text Length: 5192
# Skipping empty result for URL: https://www.express.co.uk/news/politics/1859242/rishi-sunak-replacement-tory-leader-runners-riders-kemi-badenoch
#
# Cleaning Document 65/782
# Batch 1/8
# ...
# Title Length: 88
# Body Text Length: 4769
# Inserted data into the CleanedData table for URL: https://www.afr.com/policy/foreign-affairs/if-westminster-is-hogwarts-jeremy-hunt-is-head-boy-20221020-p5br9o
#
# Cleaning Document 733/782
# Batch 8/8
# Processing document with URL: https://www.cityam.com/ai-could-help-us-with-vaccines-and-tax-cuts-jeremy-hunt-tells-davos/
# Title Length: 68
# Body Text Length: 1143
# Inserted data into the CleanedData table for URL: https://www.cityam.com/ai-could-help-us-with-vaccines-and-tax-cuts-jeremy-hunt-tells-davos/
#
# Cleaning Document 734/782
# Batch 8/8
# Processing document with URL: https://www.godalming.ac.uk/Jeremy_Hunt_visits_College.html
# Title Length: 37
# Body Text Length: 2392
# Inserted data into the CleanedData table for URL: https://www.godalming.ac.uk/Jeremy_Hunt_visits_College.html
#
# Cleaning Document 735/782
# Batch 8/8
# Processing document with URL: https://www.the-sun.com/news/5767460/jeremy-hunt-who-conservative-mp/
# Title Length: 45
# Body Text Length: 2683
# Inserted data into the CleanedData table for URL: https://www.the-sun.com/news/5767460/jeremy-hunt-who-conservative-mp/
#
# Cleaning Document 736/782
# Batch 8/8
# Processing document with URL: https://news.yahoo.com/sunak-says-jeremy-hunt-uk-112418325.html
# Title Length: 64
# Body Text Length: 2050
# Inserted data into the CleanedData table for URL: https://news.yahoo.com/sunak-says-jeremy-hunt-uk-112418325.html
#
# Cleaning Document 737/782
# Batch 8/8
# Processing document with URL: https://www.telegraph.co.uk/politics/2023/11/17/jeremy-hunt-uk-economy-tax-cuts-autum-statement/
# Title Length: 83
# Body Text Length: 7843
# Inserted data into the CleanedData table for URL: https://www.telegraph.co.uk/politics/2023/11/17/jeremy-hunt-uk-economy-tax-cuts-autum-statement/
#
# Cleaning Document 738/782
# Batch 8/8
# Processing document with URL: https://www.gov.uk/government/people/jeremy-hunt
# Title Length: 34
# Body Text Length: 1420
# Inserted data into the CleanedData table for URL: https://www.gov.uk/government/people/jeremy-hunt
#
# Cleaning Document 739/782
# Batch 8/8
# Processing document with URL: https://inews.co.uk/news/politics/tory-mps-pressure-jeremy-hunt-to-prioritise-income-tax-cuts-2866149
# Title Length: 59
# Body Text Length: 2112
# Inserted data into the CleanedData table for URL: https://inews.co.uk/news/politics/tory-mps-pressure-jeremy-hunt-to-prioritise-income-tax-cuts-2866149
#
# Cleaning Document 740/782
# Batch 8/8
# Processing document with URL: https://www.tatler.com/article/who-is-jeremy-hunt-the-new-chancellor-of-the-exchequer
# Title Length: 96
# Body Text Length: 2841
# Inserted data into the CleanedData table for URL: https://www.tatler.com/article/who-is-jeremy-hunt-the-new-chancellor-of-the-exchequer
#
# Cleaning Document 741/782
# Batch 8/8
# Processing document with URL: https://www.express.co.uk/news/politics/1859408/jeremy-hunt-dithering-taxi-tax-unfair
# Title Length: 118
# Body Text Length: 2022
# Inserted data into the CleanedData table for URL: https://www.express.co.uk/news/politics/1859408/jeremy-hunt-dithering-taxi-tax-unfair
#
# Cleaning Document 742/782
# Batch 8/8
# Processing document with URL: https://www.chartwellspeakers.com/introducing-jeremy-hunt/
# Title Length: 110
# Body Text Length: 909
# Skipping empty result for URL: https://www.chartwellspeakers.com/introducing-jeremy-hunt/
#
# Cleaning Document 743/782
# Batch 8/8
# Processing document with URL: https://metro.co.uk/2023/11/22/jeremy-hunts-family-life-tv-star-wife-properties-19859467/
# Title Length: 82
# Body Text Length: 3949
# Inserted data into the CleanedData table for URL: https://metro.co.uk/2023/11/22/jeremy-hunts-family-life-tv-star-wife-properties-19859467/
#
# Cleaning Document 744/782
# Batch 8/8
# Processing document with URL: https://www.lbc.co.uk/news/explained/jeremy-hunt-facts-background-business-politics/
# Title Length: 91
# Body Text Length: 2507
# Inserted data into the CleanedData table for URL: https://www.lbc.co.uk/news/explained/jeremy-hunt-facts-background-business-politics/
#
# Cleaning Document 745/782
# Batch 8/8
# Processing document with URL: https://en.wikipedia.org/wiki/Jeremy_Hunt
# Title Length: 23
# Body Text Length: 27627
# Inserted data into the CleanedData table for URL: https://en.wikipedia.org/wiki/Jeremy_Hunt
#
# Cleaning Document 746/782
# Batch 8/8
# Processing document with URL: https://theweek.com/politics/fiscal-headroom-can-the-uk-afford-more-tax-cuts
# Title Length: 63
# Body Text Length: 5501
# Inserted data into the CleanedData table for URL: https://theweek.com/politics/fiscal-headroom-can-the-uk-afford-more-tax-cuts
#
# Cleaning Document 747/782
# Batch 8/8
# Processing document with URL: https://www.publicwhip.org.uk/mp.php?id=uk.org.publicwhip/member/42545
# Title Length: 75
# Body Text Length: 10643
# Skipping empty result for URL: https://www.publicwhip.org.uk/mp.php?id=uk.org.publicwhip/member/42545
#
# Cleaning Document 748/782
# Batch 8/8
# Processing document with URL: https://www.instituteforgovernment.org.uk/event/jeremy-hunt
# Title Length: 62
# Body Text Length: 1039
# Skipping empty result for URL: https://www.instituteforgovernment.org.uk/event/jeremy-hunt
#
# Cleaning Document 749/782
# Batch 8/8
# Processing document with URL: https://www.wired.co.uk/article/jeremy-hunt-mp
# Title Length: 70
# Body Text Length: 3546
# Inserted data into the CleanedData table for URL: https://www.wired.co.uk/article/jeremy-hunt-mp
#
# Cleaning Document 750/782
# Batch 8/8
# Processing document with URL: https://www.france24.com/en/live-news/20221014-jeremy-hunt-softly-spoken-survivor-takes-on-hardest-role
# Title Length: 57
# Body Text Length: 3280
# Inserted data into the CleanedData table for URL: https://www.france24.com/en/live-news/20221014-jeremy-hunt-softly-spoken-survivor-takes-on-hardest-role
#
# Cleaning Document 751/782
# Batch 8/8
# Processing document with URL: https://informationcradle.com/jeremy-hunt/
# Title Length: 108
# Body Text Length: 5491
# Inserted data into the CleanedData table for URL: https://informationcradle.com/jeremy-hunt/
#
# Cleaning Document 752/782
# Batch 8/8
# Processing document with URL: https://theweek.com/news/politics/956758/jeremy-hunt-the-new-chancellor-being-thrown-in-at-the-deep-end
# Title Length: 79
# Body Text Length: 5314
# Inserted data into the CleanedData table for URL: https://theweek.com/news/politics/956758/jeremy-hunt-the-new-chancellor-being-thrown-in-at-the-deep-end
#
# Cleaning Document 753/782
# Batch 8/8
# Processing document with URL: https://www.stevebrine.com/backingJeremyHunt
# Title Length: 147
# Body Text Length: 4456
# Inserted data into the CleanedData table for URL: https://www.stevebrine.com/backingJeremyHunt
#
# Cleaning Document 754/782
# Batch 8/8
# Processing document with URL: https://time.com/6222642/jeremy-hunt-uk-finance-minister/
# Title Length: 55
# Body Text Length: 5110
# Inserted data into the CleanedData table for URL: https://time.com/6222642/jeremy-hunt-uk-finance-minister/
#
# Cleaning Document 755/782
# Batch 8/8
# Processing document with URL: https://www.thefamouspeople.com/profiles/jeremy-hunt-50214.php
# Title Length: 67
# Body Text Length: 6702
# Inserted data into the CleanedData table for URL: https://www.thefamouspeople.com/profiles/jeremy-hunt-50214.php
#
# Cleaning Document 756/782
# Batch 8/8
# Processing document with URL: https://inews.co.uk/news/politics/tax-cuts-jeremy-hunt-could-make-budget-2865585
# Title Length: 79
# Body Text Length: 2448
# Inserted data into the CleanedData table for URL: https://inews.co.uk/news/politics/tax-cuts-jeremy-hunt-could-make-budget-2865585
#
# Cleaning Document 757/782
# Batch 8/8
# Processing document with URL: https://www.britannica.com/biography/Jeremy-Hunt
# Title Length: 45
# Body Text Length: 1030
# Skipping empty result for URL: https://www.britannica.com/biography/Jeremy-Hunt
#
# Cleaning Document 758/782
# Batch 8/8
# Processing document with URL: https://www.parallelparliament.co.uk/mp/jeremy-hunt
# Title Length: 14
# Body Text Length: 65535
# Inserted data into the CleanedData table for URL: https://www.parallelparliament.co.uk/mp/jeremy-hunt
#
# Cleaning Document 759/782
# Batch 8/8
# Processing document with URL: https://www.wionews.com/world/jeremy-hunt-may-step-down-before-election-report-649987
# Title Length: 82
# Body Text Length: 1558
# Inserted data into the CleanedData table for URL: https://www.wionews.com/world/jeremy-hunt-may-step-down-before-election-report-649987
#
# Cleaning Document 760/782
# Batch 8/8
# Processing document with URL: https://www.newstatesman.com/politics/conservatives/2022/10/jeremy-hunt-chancellor-tory-saviour
# Title Length: 48
# Body Text Length: 4822
# Inserted data into the CleanedData table for URL: https://www.newstatesman.com/politics/conservatives/2022/10/jeremy-hunt-chancellor-tory-saviour
#
# Cleaning Document 761/782
# Batch 8/8
# Processing document with URL: https://www.spectator.co.uk/article/can-jeremy-hunt-really-afford-more-tax-cuts/
# Title Length: 60
# Body Text Length: 1484
# Inserted data into the CleanedData table for URL: https://www.spectator.co.uk/article/can-jeremy-hunt-really-afford-more-tax-cuts/
#
# Cleaning Document 762/782
# Batch 8/8
# Processing document with URL: https://en-academic.com/dic.nsf/enwiki/9223748https:/en-academic.com/dic.nsf/enwiki/904748
# Title Length: 24
# Body Text Length: 34015
# Inserted data into the CleanedData table for URL: https://en-academic.com/dic.nsf/enwiki/9223748https:/en-academic.com/dic.nsf/enwiki/904748
#
# Cleaning Document 763/782
# Batch 8/8
# Processing document with URL: https://jeremyforgeorgia.com/about/
# Title Length: 26
# Body Text Length: 1110
# Inserted data into the CleanedData table for URL: https://jeremyforgeorgia.com/about/
#
# Cleaning Document 764/782
# Batch 8/8
# Processing document with URL: https://www.bbc.com/news/uk-politics-48668311
# Title Length: 62
# Body Text Length: 7079
# Inserted data into the CleanedData table for URL: https://www.bbc.com/news/uk-politics-48668311
#
# Cleaning Document 765/782
# Batch 8/8
# Processing document with URL: https://www.telegraph.co.uk/politics/2024/01/14/jeremy-hunt-cabinet-mps-lose-seats-general-election-tories/
# Title Length: 85
# Body Text Length: 6368
# Inserted data into the CleanedData table for URL: https://www.telegraph.co.uk/politics/2024/01/14/jeremy-hunt-cabinet-mps-lose-seats-general-election-tories/
#
# Cleaning Document 766/782
# Batch 8/8
# Processing document with URL: https://www.lgbtconservatives.org.uk/news/my-business-politics-luke-black-interviews-jeremy-hunt-mp
# Title Length: 83
# Body Text Length: 13481
# Inserted data into the CleanedData table for URL: https://www.lgbtconservatives.org.uk/news/my-business-politics-luke-black-interviews-jeremy-hunt-mp
#
# Cleaning Document 767/782
# Batch 8/8
# Processing document with URL: https://news.yahoo.com/know-jeremy-hunt-now-britains-185312044.html
# Title Length: 69
# Body Text Length: 5218
# Inserted data into the CleanedData table for URL: https://news.yahoo.com/know-jeremy-hunt-now-britains-185312044.html
#
# Cleaning Document 768/782
# Batch 8/8
# Processing document with URL: https://www.accountancyage.com/2024/01/19/jeremy-hunt-hints-at-further-tax-cuts-at-davos-what-accountants-need-to-know/
# Title Length: 95
# Body Text Length: 3050
# Inserted data into the CleanedData table for URL: https://www.accountancyage.com/2024/01/19/jeremy-hunt-hints-at-further-tax-cuts-at-davos-what-accountants-need-to-know/
#
# Cleaning Document 769/782
# Batch 8/8
# Processing document with URL: https://www.instituteforgovernment.org.uk/ministers-reflect/jeremy-hunt
# Title Length: 38
# Body Text Length: 27850
# Inserted data into the CleanedData table for URL: https://www.instituteforgovernment.org.uk/ministers-reflect/jeremy-hunt
#
# Cleaning Document 770/782
# Batch 8/8
# Processing document with URL: https://www.economist.com/britain/2022/10/18/how-jeremy-hunt-became-the-most-powerful-person-in-britain
# Title Length: 58
# Body Text Length: 5094
# Inserted data into the CleanedData table for URL: https://www.economist.com/britain/2022/10/18/how-jeremy-hunt-became-the-most-powerful-person-in-britain
#
# Cleaning Document 771/782
# Batch 8/8
# Processing document with URL: https://world.time.com/2012/05/25/leveson-inquiry-will-british-mp-jeremy-hunt-be-another-casualty-of-the-hacking-scandal/
# Title Length: 99
# Body Text Length: 5197
# Inserted data into the CleanedData table for URL: https://world.time.com/2012/05/25/leveson-inquiry-will-british-mp-jeremy-hunt-be-another-casualty-of-the-hacking-scandal/
#
# Cleaning Document 772/782
# Batch 8/8
# Processing document with URL: https://www.pbs.org/video/jeremy-hunt-thursdays-general-election-uk-a7enm1/
# Title Length: 99
# Body Text Length: 1145
# Skipping empty result for URL: https://www.pbs.org/video/jeremy-hunt-thursdays-general-election-uk-a7enm1/
#
# Cleaning Document 773/782
# Batch 8/8
# Processing document with URL: https://www.theguardian.com/politics/2018/jul/09/jeremy-hunt-his-journey-to-the-foreign-office
# Title Length: 75
# Body Text Length: 2025
# Inserted data into the CleanedData table for URL: https://www.theguardian.com/politics/2018/jul/09/jeremy-hunt-his-journey-to-the-foreign-office
#
# Cleaning Document 774/782
# Batch 8/8
# Processing document with URL: https://www.spectator.co.uk/article/jeremy-hunt-has-difficult-decisions-ahead-of-him-on-tax-cuts/
# Title Length: 76
# Body Text Length: 1283
# Inserted data into the CleanedData table for URL: https://www.spectator.co.uk/article/jeremy-hunt-has-difficult-decisions-ahead-of-him-on-tax-cuts/
#
# Cleaning Document 775/782
# Batch 8/8
# Processing document with URL: https://theconversation.com/jeremy-hunt-where-does-the-leadership-hopeful-stand-on-brexit-exactly-119698
# Title Length: 72
# Body Text Length: 4019
# Inserted data into the CleanedData table for URL: https://theconversation.com/jeremy-hunt-where-does-the-leadership-hopeful-stand-on-brexit-exactly-119698
#
# Cleaning Document 776/782
# Batch 8/8
# Processing document with URL: https://www.morningstar.co.uk/uk/news/234368/editor-remember-june-4-2019-jeremy-hunt-does.aspx
# Title Length: 66
# Body Text Length: 12829
# Inserted data into the CleanedData table for URL: https://www.morningstar.co.uk/uk/news/234368/editor-remember-june-4-2019-jeremy-hunt-does.aspx
#
# Cleaning Document 777/782
# Batch 8/8
# Processing document with URL: https://www.standard.co.uk/news/politics/tax-cuts-election-borrowing-jeremy-hunt-budget-b1134104.html
# Title Length: 128
# Body Text Length: 3050
# Inserted data into the CleanedData table for URL: https://www.standard.co.uk/news/politics/tax-cuts-election-borrowing-jeremy-hunt-budget-b1134104.html
#
# Cleaning Document 778/782
# Batch 8/8
# Processing document with URL: https://www.bbc.com/news/uk-politics-63259600
# Title Length: 76
# Body Text Length: 3697
# Inserted data into the CleanedData table for URL: https://www.bbc.com/news/uk-politics-63259600
#
# Cleaning Document 779/782
# Batch 8/8
# Processing document with URL: https://news.sky.com/story/trusss-economic-vision-is-not-only-dead-but-the-complete-opposite-policy-will-be-pursued-12720860
# Title Length: 98
# Body Text Length: 2161
# Inserted data into the CleanedData table for URL: https://news.sky.com/story/trusss-economic-vision-is-not-only-dead-but-the-complete-opposite-policy-will-be-pursued-12720860
#
# Cleaning Document 780/782
# Batch 8/8
# Processing document with URL: https://www.bigissue.com/opinion/uk-poverty-europe-politicians-economy-centre-for-cities/
# Title Length: 66
# Body Text Length: 2745
# Inserted data into the CleanedData table for URL: https://www.bigissue.com/opinion/uk-poverty-europe-politicians-economy-centre-for-cities/
#
# Cleaning Document 781/782
# Batch 8/8
# Processing document with URL: https://www.thesun.co.uk/news/6896899/jeremy-hunt-wife-lucia-guo/
# Title Length: 91
# Body Text Length: 1854
# Inserted data into the CleanedData table for URL: https://www.thesun.co.uk/news/6896899/jeremy-hunt-wife-lucia-guo/
#
# Cleaning Document 782/782
# Batch 8/8
# Processing document with URL: https://www.independent.co.uk/news/uk/politics/jeremy-hunt-budget-chancellor-health-secretary-b2300566.html
# Title Length: 81
# Body Text Length: 5347
# Inserted data into the CleanedData table for URL: https://www.independent.co.uk/news/uk/politics/jeremy-hunt-budget-chancellor-health-secretary-b2300566.html
#
# Data cleaning and insertion process completed
